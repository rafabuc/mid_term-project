# %%
import importlib
import data_loader
importlib.reload(data_loader)
from data_loader import DataLoader

from constants import PATH_DATASETS, TARGET_COLUMN_CATEGORY_LEVEL2
from constants_v2 import PATH_DATASETS_V2

# %%
# ========================================
# STEP 1: LOAD DATA
# ========================================
print("\n" + "="*70)
print("STEP 1: LOADING DATA")
print("="*70)    
    
loader = DataLoader(
        metadata_path=f'{PATH_DATASETS}amazon_books_metadata_sample_20k.csv',
        reviews_path=f'{PATH_DATASETS}amazon_books_reviews_sample_20k.csv'
    )

# Load both datasets
metadata_df = loader.load_metadata()#nrows=1000
reviews_df = loader.load_reviews()#nrows=5000
# Out:
# 2025-11-09 15:38:10,003 - data_loader - INFO - DataLoader initialized
# 2025-11-09 15:38:10,003 - data_loader - INFO -   Metadata: datasets\amazon_books_metadata_sample_20k.csv
# 2025-11-09 15:38:10,004 - data_loader - INFO -   Reviews: datasets\amazon_books_reviews_sample_20k.csv
# 2025-11-09 15:38:10,006 - data_loader - INFO - Loading metadata from: datasets\amazon_books_metadata_sample_20k.csv
# ======================================================================
# STEP 1: LOADING DATA
# ======================================================================
# 2025-11-09 15:38:12,492 - data_loader - INFO - Successfully loaded 20,000 rows and 28 columns in 2.48s
# 2025-11-09 15:38:12,494 - data_loader - INFO - Loading reviews from: datasets\amazon_books_reviews_sample_20k.csv
# 2025-11-09 15:38:21,262 - data_loader - INFO - Successfully loaded 727,876 reviews and 12 columns in 8.77s

# %%
#metadata_df.columns
# Validate both
validation = loader.validate_schema('both')
# Out:
# 2025-11-09 15:38:21,278 - data_loader - INFO - Validating schema for: both
# 2025-11-09 15:38:21,285 - data_loader - INFO - ✓ Metadata schema validation passed
# 2025-11-09 15:38:21,287 - data_loader - INFO - Metadata optional columns: 10/10
# 2025-11-09 15:38:21,289 - data_loader - INFO - ✓ Reviews schema validation passed
# 2025-11-09 15:38:21,291 - data_loader - INFO - Reviews optional columns: 8/8

# %%
   # Print comprehensive summary
loader.print_summary()
# Out:
# 2025-11-09 15:38:27,025 - data_loader - INFO - Generating data summary...
# 2025-11-09 15:38:27,172 - data_loader - INFO - Data summary generated successfully
# 2025-11-09 15:38:27,174 - data_loader - INFO - Generating reviews summary...
# ======================================================================
# 📚 BOOK METADATA & REVIEWS SUMMARY
# ======================================================================
#
# 📊 METADATA - BASIC INFORMATION:
#   • Total Books: 20,000
#   • Total Columns: 28
#   • Memory Usage: 271.43 MB
#   • Duplicates: 0
#
# 🏷️  CATEGORY STATISTICS:
#
#   category_level_2_sub:
#     - Unique Categories: 50
#     - Missing Values: 118
#     - Top 3 Categories:
#       1. Literature & Fiction: 5,174 books
#       2. Mystery, Thriller & Suspense: 2,631 books
#       3. Children's Books: 1,952 books
#
# 📝 TEXT FEATURES:
#
#   title:
#     - Missing: 0
#     - Avg Length: 47 characters
#     - Range: 1 - 200 chars
#
#   description:
#     - Missing: 0
#     - Avg Length: 5154 characters
#     - Range: 10 - 254372 chars
#
#   features_text:
#     - Missing: 33
#     - Avg Length: 1168 characters
#     - Range: 1 - 24835 chars
#
# 🔢 NUMERICAL FEATURES:
#
#   price_numeric:
#     - Count: 20,000
#     - Mean: 18.78
#     - Range: 5.01 - 11568.31
#     - Missing: 0
#
#   page_count:
#     - Count: 15,544
#     - Mean: 330.96
#     - Range: 0.0 - 9998.0
#     - Missing: 4,456
#
#   average_rating:
#     - Count: 20,000
#     - Mean: 4.47
#     - Range: 2.5 - 5.0
#     - Missing: 0
#
#   rating_number:
#     - Count: 20,000
#     - Mean: 2488.5
#     - Range: 200 - 278592
#     - Missing: 0
# 2025-11-09 15:38:27,921 - data_loader - INFO - Reviews summary generated successfully
# ======================================================================
# 💬 REVIEWS SUMMARY
# ======================================================================
#
# 📊 BASIC STATISTICS:
#   • Total Reviews: 727,876
#   • Unique Users: 593,235
#   • Unique Books Reviewed: 19,991
#   • Average Rating: 4.42
#   • Median Rating: 5.0
#
# ⭐ RATING DISTRIBUTION:
#   1★ : 29,554 reviews (4.1%)
#   2★ : 28,275 reviews (3.9%)
#   3★ : 52,300 reviews (7.2%)
#   4★ : 116,045 reviews (15.9%)
#   5★ : 501,702 reviews (68.9%)
#
# 📝 REVIEW TEXT:
#   • Avg Length: 432 characters
#   • Median Length: 167 characters
#   • Range: 1 - 32285 chars
#   • Missing Text: 112
#
# ✅ VERIFIED PURCHASES:
#   • Verified: 523,636 (71.94%)
#   • Not Verified: 204,240
#
# 👍 HELPFUL VOTES:
#   • Total Votes: 1,430,192
#   • Avg per Review: 1.96
#   • Reviews with Votes: 240,043
#
# 📅 TEMPORAL DISTRIBUTION:
#   • Date Range: 1997 - 2023
#   • Top 3 Years:
#     1. 1997: 137 reviews
#     2. 1998: 572 reviews
#     3. 1999: 1,427 reviews
#
# ======================================================================

# %%
reviews_summary = loader.get_reviews_summary()
#print(reviews_summary)
# Out:
# 2025-11-09 15:38:32,417 - data_loader - INFO - Generating reviews summary...
# 2025-11-09 15:38:33,180 - data_loader - INFO - Reviews summary generated successfully

# %%
# Get reviews per book statistics
reviews_per_book = loader.get_reviews_per_book_stats()
print(reviews_per_book.head(10))
# Out:
# 2025-11-09 15:38:35,740 - data_loader - INFO - Analyzing reviews per book...
# 2025-11-09 15:38:36,064 - data_loader - INFO - Analyzed 19,991 books
#       parent_asin  num_reviews  avg_rating  rating_std  unique_users
# 19096  B00CNQ7HAU        14892    4.493956    0.807029         14752
# 19306  B00UEKRTW8         7799    3.986152    1.154877          7720
# 19183  B00G3L6KQI         4492    4.625779    0.785633          4464
# 19219  B00IJJUIMY         4222    4.383468    0.891159          4194
# 4330   0439023521         3150    4.475873    1.000741          3100
# 2717   0316460834         2848    4.795646    0.689391          2835
# 398    0061537969         2520    4.631746    0.879446          2490
# 19336  B0106E2CO6         2333    4.469781    0.901000          2308
# 8148   0811879542         2137    4.745905    0.787611          2124
# 13796  1565125606         2025    4.291852    1.126073          2009

# %%
    
# Join with minimum 5 reviews per book
joined_df = loader.join_metadata_reviews(
        how='inner',
        min_reviews_per_book=5
)
print(f'\n{"="*60}')
print(f"\nJoined data shape:\n {joined_df.shape}")
    
# Get rating distribution by category
rating_by_category = loader.get_rating_distribution_by_category(TARGET_COLUMN_CATEGORY_LEVEL2)
print(f'\n{"="*60}')
print(f"\nRating distribution by {TARGET_COLUMN_CATEGORY_LEVEL2} category:\n")
print(rating_by_category)

loader.export_summary_report(f'{PATH_DATASETS_V2}complete_data_report.txt')


print(f"\nLoaded:")
print(f"  Metadata: {len(metadata_df):,} books")
print(f"  Reviews: {len(reviews_df):,} reviews")
# Out:
# 2025-11-09 15:40:22,226 - data_loader - INFO - Joining metadata and reviews with 'inner' join...
# 2025-11-09 15:40:22,704 - data_loader - INFO - Filtered to books with >=5 reviews: 13,612 books, 714,864 reviews
# 2025-11-09 15:40:24,093 - data_loader - INFO - Join complete: 714,864 rows (20,000 books × 714,864 reviews)
# 2025-11-09 15:40:24,737 - data_loader - INFO - Join statistics: 13,612 unique books, 584,538 unique users
# 2025-11-09 15:40:25,081 - data_loader - INFO - Analyzing rating distribution by category_level_2_sub...
# 2025-11-09 15:40:25,091 - data_loader - INFO - Joining metadata and reviews with 'inner' join...
# ============================================================
#
# Joined data shape:
#  (714864, 39)
# 2025-11-09 15:40:27,183 - data_loader - INFO - Join complete: 727,876 rows (20,000 books × 727,876 reviews)
# 2025-11-09 15:40:27,807 - data_loader - INFO - Join statistics: 19,991 unique books, 593,235 unique users
# 2025-11-09 15:40:28,021 - data_loader - INFO - Analyzed 50 categories
# 2025-11-09 15:40:28,173 - data_loader - INFO - Exporting summary report to: ./artifacts_v2/datasets/complete_data_report.txt
# 2025-11-09 15:40:28,176 - data_loader - INFO - Generating data summary...
# 2025-11-09 15:40:28,351 - data_loader - INFO - Data summary generated successfully
# 2025-11-09 15:40:28,352 - data_loader - INFO - Checking missing values...
# ============================================================
#
# Rating distribution by category_level_2_sub category:
#
#                 category_level_2_sub  num_reviews  avg_rating  rating_std  \
# 29              Literature & Fiction       157693    4.266974    1.149147
# 31      Mystery, Thriller & Suspense       129952    4.224437    1.123387
# 10                  Children's Books       101017    4.638279    0.908919
# 46                Teen & Young Adult        35216    4.460047    0.982247
# 3              Biographies & Memoirs        32847    4.454166    1.038777
# 11          Christian Books & Bibles        27946    4.673549    0.756218
# 14            Cookbooks, Food & Wine        27807    4.539900    0.989324
# 15            Crafts, Hobbies & Home        20495    4.581800    0.916932
# 1                 Arts & Photography        18981    4.546388    0.964556
# 34        Politics & Social Sciences        18217    4.458747    1.058231
# 23                           History        17443    4.474918    0.978902
# 8                   Business & Money        16932    4.493681    0.984504
# 41         Science Fiction & Fantasy        14575    4.203087    1.184006
# 22         Health, Fitness & Dieting        12130    4.542539    0.981675
# 37                         Reference        10804    4.543040    0.930173
# 40                    Science & Math        10627    4.426837    1.059400
# 24             Humor & Entertainment        10026    4.368342    1.099205
# 12           Comics & Graphic Novels         7762    4.534141    0.974184
# 38           Religion & Spirituality         7074    4.631750    0.865614
# 19      Engineering & Transportation         6210    4.528986    0.947765
# 43                         Self-Help         6041    4.651382    0.828688
# 32      New, Used & Rental Textbooks         5912    4.408999    1.134429
# 44                 Sports & Outdoors         5091    4.481045    1.022432
# 13            Computers & Technology         4951    4.282569    1.164950
# 39                           Romance         4784    4.457567    0.967741
# 49                            Travel         3512    4.401765    1.083013
# 18              Education & Teaching         2835    4.486420    1.037107
# 30                     Medical Books         1956    4.438650    1.064574
# 33         Parenting & Relationships         1793    4.582822    0.917328
# 25                      LGBTQ+ Books         1719    4.223386    1.197159
# 7                         Boxed Sets         1624    4.606527    0.899637
# 47                  Test Preparation          808    4.443069    1.077758
# 2                 Best Books of 2016          360    4.600000    0.941758
# 45  Stationery, Journals & Notebooks          343    4.673469    0.775028
# 27                               Law          229    4.519651    1.015584
# 16                    Deals in Books          175    4.514286    0.945997
# 0                      ASINs for HQP           94    4.648936    0.935644
# 20            Foreign Language Books           94    4.382979    1.127433
# 42         Seasonal Children's Books           91    4.329670    1.096002
# 26                       Large Print           86    4.593023    0.831411
# 35                      Popover Test           77    4.844156    0.586357
# 28                 Libros en español           39    4.846154    0.431549
# 17       Dear Santa Children's Books           26    4.846154    0.612686
# 9                          Calendars           19    4.631579    0.955134
# 4                      Blowout Books           12    4.333333    1.073087
# 5                    Books Markdowns           10    2.900000    1.100505
# 48             Textbook Rental ASINs           10    4.500000    1.080123
# 36                  Popular Suspense            5    3.200000    1.643168
# 21                   Harlequin Store            3    4.000000    1.000000
# 6                        Books on CD            1    5.000000         NaN
#
#     median_rating  num_books
# 29            5.0       5174
# 31            5.0       2631
# 10            5.0       1952
# 46            5.0        933
# 3             5.0        992
# 11            5.0       1046
# 14            5.0        395
# 15            5.0        386
# 1             5.0        437
# 34            5.0        556
# 23            5.0        620
# 8             5.0        436
# 41            5.0        649
# 22            5.0        391
# 37            5.0        224
# 40            5.0        233
# 24            5.0        237
# 12            5.0        286
# 38            5.0        250
# 19            5.0        130
# 43            5.0        252
# 32            5.0        182
# 44            5.0        154
# 13            5.0        106
# 39            5.0        581
# 49            5.0        139
# 18            5.0         99
# 30            5.0        132
# 33            5.0         60
# 25            5.0         72
# 7             5.0         30
# 47            5.0         13
# 2             5.0          1
# 45            5.0          7
# 27            5.0         10
# 16            5.0          7
# 0             5.0          4
# 20            5.0         19
# 42            5.0          1
# 26            5.0         26
# 35            5.0          2
# 28            5.0          7
# 17            5.0          1
# 9             5.0          1
# 4             5.0          3
# 5             3.0          1
# 48            5.0          2
# 36            4.0          1
# 21            4.0          1
# 6             5.0          1
# 2025-11-09 15:40:28,392 - data_loader - WARNING - Found missing values in required columns:
#                   column  missing_count  missing_percentage   dtype
# 13  category_level_2_sub            118                0.59  object
# 2025-11-09 15:40:28,397 - data_loader - INFO - Analyzing category distribution for: category_level_2_sub
# 2025-11-09 15:40:28,399 - data_loader - INFO - Found 20 unique categories at level 'category_level_2_sub'
# 2025-11-09 15:40:28,401 - data_loader - INFO - Generating reviews summary...
# 2025-11-09 15:40:29,244 - data_loader - INFO - Reviews summary generated successfully
# 2025-11-09 15:40:29,245 - data_loader - INFO - Analyzing reviews per book...
# 2025-11-09 15:40:29,646 - data_loader - INFO - Analyzed 19,991 books
# 2025-11-09 15:40:29,661 - data_loader - INFO - Report exported successfully to: ./artifacts_v2/datasets/complete_data_report.txt
# Loaded:
#   Metadata: 20,000 books
#   Reviews: 727,876 reviews

# %%
import importlib
import data_preprocessor
importlib.reload(data_preprocessor)

import constants_v2
importlib.reload(constants_v2)
from data_preprocessor import DataPreprocessor

from constants_v2 import PATH_ARTIFACTS_V2, SAMPLE_METADATA_FILE_V2, CLASS_WEIGHTS_FILE_V2

# %%
# ========================================
# STEP 2: INITIALIZE PREPROCESSOR
# ========================================
print("\n" + "="*70)
print("STEP 2: INITIALIZING PREPROCESSOR")
print("="*70)

#decrease categories choosen 
#min_samples_per_category 
# Step 2: Preprocess
preprocessor = DataPreprocessor(
        min_samples_per_category=100,    # Minimum 100 books per category
        sampling_percentage=0.5,         # Use 20% of data (for faster training)
        balance_strategy='class_weight', # Calculate weights for imbalanced classes
        min_reviews_per_book=5          # Minimum 5 reviews per book
)
# Out:
# 2025-11-09 15:51:41,263 - data_preprocessor - INFO - DataPreprocessor initialized
# 2025-11-09 15:51:41,263 - data_preprocessor - INFO -   Min samples per category: 100
# 2025-11-09 15:51:41,264 - data_preprocessor - INFO -   Sampling percentage: 50.0%
# 2025-11-09 15:51:41,265 - data_preprocessor - INFO -   Balance strategy: class_weight
# 2025-11-09 15:51:41,266 - data_preprocessor - INFO -   Min reviews per book: 5
# ======================================================================
# STEP 2: INITIALIZING PREPROCESSOR
# ======================================================================

# %%
# ========================================
# STEP 2.1: CLEAN METADATA
# ========================================
print("\n" + "="*70)
print("STEP 2.1: CLEANING METADATA")
print("="*70)
    
# Clean both datasets
clean_metadata = preprocessor.clean_metadata(metadata_df)
# Out:
# 2025-11-09 15:51:44,437 - data_preprocessor - INFO - ======================================================================
# 2025-11-09 15:51:44,438 - data_preprocessor - INFO - CLEANING METADATA
# 2025-11-09 15:51:44,439 - data_preprocessor - INFO - ======================================================================
# 2025-11-09 15:51:44,450 - data_preprocessor - INFO -
# [1/5] Removing duplicates...
# 2025-11-09 15:51:44,473 - data_preprocessor - INFO -   Removed 0 duplicates
# 2025-11-09 15:51:44,474 - data_preprocessor - INFO -
# [2/5] Handling missing descriptions...
# ======================================================================
# STEP 2.1: CLEANING METADATA
# ======================================================================
# 2025-11-09 15:51:44,926 - data_preprocessor - INFO -   Missing descriptions before: 0
# 2025-11-09 15:51:44,927 - data_preprocessor - INFO -   Missing descriptions after: 0
# 2025-11-09 15:51:44,928 - data_preprocessor - INFO -   Filled: 0
# 2025-11-09 15:51:44,929 - data_preprocessor - INFO -
# [3/5] Cleaning text fields...
# 2025-11-09 15:51:44,929 - data_preprocessor - INFO - Cleaning text field with 20000 entries...
# 2025-11-09 15:51:45,027 - data_preprocessor - INFO - Text cleaning complete:
# 2025-11-09 15:51:45,028 - data_preprocessor - INFO -   Non-empty before: 20000
# 2025-11-09 15:51:45,029 - data_preprocessor - INFO -   Non-empty after: 20000
# 2025-11-09 15:51:45,031 - data_preprocessor - INFO - Cleaning text field with 20000 entries...
# 2025-11-09 15:51:48,478 - data_preprocessor - INFO - Text cleaning complete:
# 2025-11-09 15:51:48,479 - data_preprocessor - INFO -   Non-empty before: 20000
# 2025-11-09 15:51:48,480 - data_preprocessor - INFO -   Non-empty after: 20000
# 2025-11-09 15:51:48,488 - data_preprocessor - INFO - Cleaning text field with 20000 entries...
# 2025-11-09 15:51:49,426 - data_preprocessor - INFO - Text cleaning complete:
# 2025-11-09 15:51:49,427 - data_preprocessor - INFO -   Non-empty before: 19967
# 2025-11-09 15:51:49,428 - data_preprocessor - INFO -   Non-empty after: 19967
# 2025-11-09 15:51:49,430 - data_preprocessor - INFO - Cleaning text field with 20000 entries...
# 2025-11-09 15:51:49,509 - data_preprocessor - INFO - Text cleaning complete:
# 2025-11-09 15:51:49,510 - data_preprocessor - INFO -   Non-empty before: 20000
# 2025-11-09 15:51:49,512 - data_preprocessor - INFO -   Non-empty after: 19982
# 2025-11-09 15:51:49,514 - data_preprocessor - INFO -
# [4/5] Removing books without category...
# 2025-11-09 15:51:49,538 - data_preprocessor - INFO -   Removed 118 books without category
# 2025-11-09 15:51:49,540 - data_preprocessor - INFO -
# [6/5] Cleaning numerical fields...
# 2025-11-09 15:51:49,546 - data_preprocessor - INFO -
# ✓ Metadata cleaning complete
# 2025-11-09 15:51:49,548 - data_preprocessor - INFO -   Original: 20,000 books
# 2025-11-09 15:51:49,549 - data_preprocessor - INFO -   Final: 19,882 books
# 2025-11-09 15:51:49,549 - data_preprocessor - INFO -   Removed: 118 books

# %%
# ========================================
# STEP 2.2: CLEAN REVIEWS
# ========================================
print("\n" + "="*70)
print("STEP 2.2: CLEANING REVIEWS")
print("="*70)
    
clean_reviews = preprocessor.clean_reviews(reviews_df)
# Out:
# 2025-11-09 15:51:52,308 - data_preprocessor - INFO -
# ======================================================================
# 2025-11-09 15:51:52,309 - data_preprocessor - INFO - CLEANING REVIEWS
# 2025-11-09 15:51:52,309 - data_preprocessor - INFO - ======================================================================
# 2025-11-09 15:51:52,380 - data_preprocessor - INFO -
# [1/5] Removing duplicates...
# ======================================================================
# STEP 2.2: CLEANING REVIEWS
# ======================================================================
# 2025-11-09 15:51:53,621 - data_preprocessor - INFO -   Removed 7892 duplicate reviews
# 2025-11-09 15:51:53,622 - data_preprocessor - INFO -
# [2/5] Validating ratings...
# 2025-11-09 15:51:53,773 - data_preprocessor - INFO -   Removed 0 reviews with invalid ratings
# 2025-11-09 15:51:53,775 - data_preprocessor - INFO -
# [3/5] Cleaning review text...
# 2025-11-09 15:51:53,776 - data_preprocessor - INFO - Cleaning text field with 719984 entries...
# 2025-11-09 15:52:05,930 - data_preprocessor - INFO - Text cleaning complete:
# 2025-11-09 15:52:05,932 - data_preprocessor - INFO -   Non-empty before: 719874
# 2025-11-09 15:52:05,933 - data_preprocessor - INFO -   Non-empty after: 719287
# 2025-11-09 15:52:06,263 - data_preprocessor - INFO -   Removed 697 reviews with empty text
# 2025-11-09 15:52:06,265 - data_preprocessor - INFO -
# [4/5] Processing verified_purchase field...
# 2025-11-09 15:52:06,270 - data_preprocessor - INFO -   Verified purchases: 517,441 (71.9%)
# 2025-11-09 15:52:06,271 - data_preprocessor - INFO -
# [5/5] Cleaning helpful_vote field...
# 2025-11-09 15:52:06,280 - data_preprocessor - INFO -
# ✓ Reviews cleaning complete
# 2025-11-09 15:52:06,282 - data_preprocessor - INFO -   Original: 727,876 reviews
# 2025-11-09 15:52:06,282 - data_preprocessor - INFO -   Final: 719,287 reviews
# 2025-11-09 15:52:06,283 - data_preprocessor - INFO -   Removed: 8,589 reviews

# %%
# ========================================
# STEP 2.3: ENRICH METADATA WITH REVIEWS
# ========================================
# Enrich metadata with review features
enriched_metadata = preprocessor.enrich_with_reviews(clean_metadata, clean_reviews)
# Out:
# 2025-11-09 15:52:14,734 - data_preprocessor - INFO -
# ======================================================================
# 2025-11-09 15:52:14,735 - data_preprocessor - INFO - ENRICHING METADATA WITH REVIEW FEATURES
# 2025-11-09 15:52:14,736 - data_preprocessor - INFO - ======================================================================
# 2025-11-09 15:52:14,736 - data_preprocessor - INFO -
# Input data:
# 2025-11-09 15:52:14,737 - data_preprocessor - INFO -   Metadata books: 19,882
# 2025-11-09 15:52:14,737 - data_preprocessor - INFO -   Total reviews: 719,287
# 2025-11-09 15:52:15,017 - data_preprocessor - INFO -
# Aggregating review features...
# 2025-11-09 15:52:17,194 - data_preprocessor - INFO -
# Aggregated features for 19,987 books
# 2025-11-09 15:52:17,194 - data_preprocessor - INFO - Features created: ['parent_asin', 'review_count', 'avg_rating_from_reviews', 'rating_std', 'verified_purchase_pct', 'helpful_votes_total', 'review_text_avg_length']
# 2025-11-09 15:52:17,195 - data_preprocessor - INFO -
# Merging with metadata...
# 2025-11-09 15:52:17,242 - data_preprocessor - INFO -
# Handling books without reviews...
# d:\workspace\datatalks-club\DataTalksClub\mid-term-project\data_preprocessor.py:434: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   enriched[col].fillna(val, inplace=True)
# 2025-11-09 15:52:17,247 - data_preprocessor - INFO -   Books without reviews: 13
# 2025-11-09 15:52:17,248 - data_preprocessor - INFO -   Filled with default values
# 2025-11-09 15:52:17,249 - data_preprocessor - INFO -
# ✓ Enrichment complete
# 2025-11-09 15:52:17,250 - data_preprocessor - INFO -
# Review features summary:
# 2025-11-09 15:52:17,252 - data_preprocessor - INFO -   Avg reviews per book: 36.1
# 2025-11-09 15:52:17,253 - data_preprocessor - INFO -   Max reviews per book: 14750
# 2025-11-09 15:52:17,255 - data_preprocessor - INFO -   Avg rating: 4.38

# %%
# ========================================
# STEP 2.4: FILTER RARE CATEGORIES (categories with less than 50)
# ========================================    
# Filter and sample
filtered_metadata  = preprocessor.filter_rare_categories(enriched_metadata,
        category_column=TARGET_COLUMN_CATEGORY_LEVEL2)

print(f"\nFiltered metadata:")
print(f"  Books: {len(filtered_metadata):,}")
print(f"  Categories: {filtered_metadata[TARGET_COLUMN_CATEGORY_LEVEL2].nunique()}")
# Out:
# 2025-11-09 15:52:21,343 - data_preprocessor - INFO -
# ======================================================================
# 2025-11-09 15:52:21,343 - data_preprocessor - INFO - FILTERING RARE CATEGORIES
# 2025-11-09 15:52:21,344 - data_preprocessor - INFO - ======================================================================
# 2025-11-09 15:52:21,347 - data_preprocessor - INFO -
# Before filtering:
# 2025-11-09 15:52:21,348 - data_preprocessor - INFO -   Total books: 19,882
# 2025-11-09 15:52:21,349 - data_preprocessor - INFO -   Total categories: 50
# 2025-11-09 15:52:21,385 - data_preprocessor - INFO -
# After filtering (min 100 samples):
# 2025-11-09 15:52:21,386 - data_preprocessor - INFO -   Total books: 19,612
# 2025-11-09 15:52:21,388 - data_preprocessor - INFO -   Total categories: 28
# 2025-11-09 15:52:21,389 - data_preprocessor - INFO -   Removed categories: 22
# 2025-11-09 15:52:21,390 - data_preprocessor - INFO -   Removed books: 270
# 2025-11-09 15:52:21,393 - data_preprocessor - INFO -
# Removed categories: ['Large Print', 'LGBTQ+ Books', 'Popular Suspense', 'Blowout Books', 'Foreign Language Books', 'Calendars', 'Boxed Sets', 'Libros en español', 'Popover Test', 'Textbook Rental ASINs']
# Filtered metadata:
#   Books: 19,612
#   Categories: 28

# %%
   
# ========================================
# STEP 2.5: FILTER BY REVIEW COUNT (minimal reviews)
# ========================================
print("\n" + "="*70)
print("STEP 2.5: FILTERING BY REVIEW COUNT")
print("="*70)
    
filtered_metadata = preprocessor.filter_by_review_count( filtered_metadata)
# Out:
# 2025-11-09 15:52:27,429 - data_preprocessor - INFO -
# ======================================================================
# 2025-11-09 15:52:27,431 - data_preprocessor - INFO - FILTERING BY REVIEW COUNT
# 2025-11-09 15:52:27,433 - data_preprocessor - INFO - ======================================================================
# 2025-11-09 15:52:27,434 - data_preprocessor - INFO -
# Filtering books with less than 5 reviews...
# 2025-11-09 15:52:27,456 - data_preprocessor - INFO -   Books before: 19,612
# 2025-11-09 15:52:27,457 - data_preprocessor - INFO -   Books after: 13,360
# 2025-11-09 15:52:27,458 - data_preprocessor - INFO -   Removed: 6,252 books
# ======================================================================
# STEP 2.5: FILTERING BY REVIEW COUNT
# ======================================================================

# %%
# ========================================
# STEP 2.6: STRATIFIED SAMPLING
# ========================================
print("\n" + "="*70)
print("STEP 2.6: STRATIFIED SAMPLING")
print("="*70)

sampled_metadata  = preprocessor.sample_data(filtered_metadata,
        category_column=TARGET_COLUMN_CATEGORY_LEVEL2,
        random_state=42)

print(f"\nSampled metadata:")
print(f"  Books: {len(sampled_metadata):,}")
print(f"  Categories: {sampled_metadata[TARGET_COLUMN_CATEGORY_LEVEL2].nunique()}")
# Out:
# 2025-11-09 15:52:35,796 - data_preprocessor - INFO -
# ======================================================================
# 2025-11-09 15:52:35,797 - data_preprocessor - INFO - STRATIFIED SAMPLING
# 2025-11-09 15:52:35,797 - data_preprocessor - INFO - ======================================================================
# 2025-11-09 15:52:35,798 - data_preprocessor - INFO -
# Sampling 50.0% of data
# 2025-11-09 15:52:35,798 - data_preprocessor - INFO -   Original: 13,360 books
# 2025-11-09 15:52:35,799 - data_preprocessor - INFO -   Target: 6,680 books
# ======================================================================
# STEP 2.6: STRATIFIED SAMPLING
# ======================================================================
# d:\workspace\datatalks-club\DataTalksClub\mid-term-project\data_preprocessor.py:605: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_sampled = df.groupby(category_column, group_keys=False).apply(
# 2025-11-09 15:52:36,385 - data_preprocessor - INFO -   Sampled: 6,681 books
# 2025-11-09 15:52:36,387 - data_preprocessor - INFO -
# Verifying category distribution:
# 2025-11-09 15:52:36,393 - data_preprocessor - INFO -   Literature & Fiction: 24.8% → 24.8%
# 2025-11-09 15:52:36,394 - data_preprocessor - INFO -   Mystery, Thriller & Suspense: 12.9% → 12.9%
# 2025-11-09 15:52:36,395 - data_preprocessor - INFO -   Children's Books: 11.1% → 11.1%
# 2025-11-09 15:52:36,396 - data_preprocessor - INFO -   Christian Books & Bibles: 5.4% → 5.4%
# 2025-11-09 15:52:36,399 - data_preprocessor - INFO -   Biographies & Memoirs: 5.2% → 5.2%
# Sampled metadata:
#   Books: 6,681
#   Categories: 28

# %%
# ========================================
# STEP 2.7: CALCULATE CLASS WEIGHTS
# ========================================
    
# Calculate class weights
class_weights = preprocessor.calculate_class_weights(sampled_metadata, 
                                                      category_column=TARGET_COLUMN_CATEGORY_LEVEL2)
# Out:
# 2025-11-09 15:52:46,783 - data_preprocessor - INFO -
# ======================================================================
# 2025-11-09 15:52:46,784 - data_preprocessor - INFO - CALCULATING CLASS WEIGHTS
# 2025-11-09 15:52:46,785 - data_preprocessor - INFO - ======================================================================
# 2025-11-09 15:52:48,407 - data_preprocessor - INFO -
# Balance strategy: class_weight
# 2025-11-09 15:52:48,408 - data_preprocessor - INFO - Computed weights for 28 categories
# 2025-11-09 15:52:48,409 - data_preprocessor - INFO -
# Top 5 minority classes (highest weights):
# 2025-11-09 15:52:48,411 - data_preprocessor - INFO -   Education & Teaching: weight=6.63, samples=36
# 2025-11-09 15:52:48,413 - data_preprocessor - INFO -   Medical Books: weight=6.63, samples=36
# 2025-11-09 15:52:48,415 - data_preprocessor - INFO -   Computers & Technology: weight=5.08, samples=47
# 2025-11-09 15:52:48,416 - data_preprocessor - INFO -   Travel: weight=4.68, samples=51
# 2025-11-09 15:52:48,416 - data_preprocessor - INFO -   Engineering & Transportation: weight=4.42, samples=54

# %%
# ========================================
# STEP 2.8: SAVE CLASS WEIGHTS  AND SAMPLED DATA
# ========================================
preprocessor.save_preprocessed_data(sampled_metadata,
        output_path=SAMPLE_METADATA_FILE_V2,
        save_class_weights=True,
        class_weights=class_weights,
        weights_path=CLASS_WEIGHTS_FILE_V2)
# Out:
# ✓ Directory ensured: artifacts_v2\dataset
# ✓ CSV saved: ./artifacts_v2//dataset/sampled_metadata.csv
# ✓ Directory ensured: artifacts_v2\dataset
# ✓ Class weights saved: ./artifacts_v2//dataset/class_weights.json

# %%
# ========================================
# FINAL SUMMARY
# ========================================    
# Print summary
preprocessor.print_preprocessing_summary()
    
print("\n" + "="*70)
print("PREPROCESSING COMPLETE")
print("="*70)
    
print(f"\nFinal dataset statistics:")
print(f"  Total books: {len(sampled_metadata):,}")
print(f"  Total categories: {sampled_metadata[TARGET_COLUMN_CATEGORY_LEVEL2].nunique()}")
print(f"  Total columns: {len(sampled_metadata.columns)}")
print(f"  Avg reviews per book: {sampled_metadata['review_count'].mean():.1f}")
print(f"  Avg rating: {sampled_metadata['avg_rating_from_reviews'].mean():.2f}")
    
print("\nTop 5 categories by count:")
top_categories = sampled_metadata[TARGET_COLUMN_CATEGORY_LEVEL2].value_counts().head(5)
for cat, count in top_categories.items():
        pct = (count / len(sampled_metadata)) * 100
        print(f"  {cat}: {count:,} books ({pct:.1f}%)")
# Out:
# ======================================================================
# PREPROCESSING SUMMARY
# ======================================================================
#
# 📚 METADATA CLEANING:
#   Original books: 20,000
#   Final books: 19,882
#   Duplicates removed: 0
#   Descriptions filled: 0
#   No category removed: 118
#
# 💬 REVIEWS CLEANING:
#   Original reviews: 727,876
#   Final reviews: 719,287
#   Duplicates removed: 7892
#   Invalid ratings removed: 0
#   Empty text removed: 697
#
# ⭐ ENRICHMENT:
#   Books with reviews: 19,987
#   Books without reviews: 13
#   Features added: 6
#
# 🔍 FILTERING:
#   Original books: 19,882
#   Final books: 19,612
#   Original categories: 50
#   Final categories: 28
#   Removed categories: 22
#
# 📊 SAMPLING:
#   Original: 13,360
#   Sampled: 6,681
#   Percentage: 50%
#
# ======================================================================
#
# ======================================================================
# PREPROCESSING COMPLETE
# ======================================================================
#
# Final dataset statistics:
#   Total books: 6,681
#   Total categories: 28
#   Total columns: 34
#   Avg reviews per book: 50.7
#   Avg rating: 4.39
#
# Top 5 categories by count:
#   Literature & Fiction: 1,655 books (24.8%)
#   Mystery, Thriller & Suspense: 860 books (12.9%)
#   Children's Books: 744 books (11.1%)
#   Christian Books & Bibles: 362 books (5.4%)
#   Biographies & Memoirs: 350 books (5.2%)

# %%
import importlib
import data_splitter
importlib.reload(data_splitter)
from data_splitter import DataSplitter
from constants import TARGET_COLUMN_CATEGORY_LEVEL2
from constants_v2 import TRAIN_FILE_V2, TEST_FILE_V2, INFO_FILE_V2
from constants_v2 import SAMPLE_METADATA_FILE_V2  , PATH_ARTIFACTS_V2
print("\n" + "=" * 80)
print("DATA SPLITTER ")
print("=" * 80)
    
# Inicializar splitter
splitter = DataSplitter(
        test_size=0.2,           # 20% para test
        random_state=42,         # Reproducibilidad
        target_column=TARGET_COLUMN_CATEGORY_LEVEL2,
        train_file_name=TRAIN_FILE_V2,
        test_file_name=TEST_FILE_V2,
        info_file_name=INFO_FILE_V2
)
# Out:
# 2025-11-09 15:54:11,379 - data_splitter - INFO - DataSplitter initialized
# 2025-11-09 15:54:11,380 - data_splitter - INFO -   test_size: 0.2
# 2025-11-09 15:54:11,381 - data_splitter - INFO -   random_state: 42
# 2025-11-09 15:54:11,381 - data_splitter - INFO -   target_column: category_level_2_sub
# ================================================================================
# DATA SPLITTER
# ================================================================================

# %%
# Ejecutar pipeline completo
results = splitter.run_pipeline(
        sampled_metadata_path=SAMPLE_METADATA_FILE_V2,
        output_dir=PATH_ARTIFACTS_V2
    )
    
print("\n✅ Data splitting completed!")
print(f"\nAccess files in: {PATH_ARTIFACTS_V2}/")
print("  - train_metadata.csv")
print("  - test_metadata.csv")
print("  - split_info.json")
# Out:
# 2025-11-09 15:54:14,703 - data_splitter - INFO -
# ================================================================================
# 2025-11-09 15:54:14,704 - data_splitter - INFO - RUNNING DATA SPLITTER PIPELINE
# 2025-11-09 15:54:14,705 - data_splitter - INFO - ================================================================================
# 2025-11-09 15:54:14,705 - data_splitter - INFO - ================================================================================
# 2025-11-09 15:54:14,706 - data_splitter - INFO - LOADING SAMPLED METADATA
# 2025-11-09 15:54:14,706 - data_splitter - INFO - ================================================================================
# 2025-11-09 15:54:14,707 - data_splitter - INFO - Loading: ./artifacts_v2//dataset/sampled_metadata.csv
# 2025-11-09 15:54:15,778 - data_splitter - INFO - ✓ Data loaded successfully
# 2025-11-09 15:54:15,780 - data_splitter - INFO -   Shape: (6681, 34)
# 2025-11-09 15:54:15,781 - data_splitter - INFO -   Columns: ['title', 'subtitle', 'author_name', 'author_about', 'publisher', 'publisher_date', 'format', 'page_count', 'language', 'isbn_10', 'isbn_13', 'main_category', 'category_level_1_main', 'category_level_2_sub', 'category_level_3_detail', 'average_rating', 'rating_number', 'price', 'price_numeric', 'description', 'features_text', 'dimensions', 'item_weight', 'images', 'videos', 'store', 'parent_asin', 'bought_together', 'review_count', 'avg_rating_from_reviews', 'rating_std', 'verified_purchase_pct', 'helpful_votes_total', 'review_text_avg_length']
# 2025-11-09 15:54:15,782 - data_splitter - INFO -
# Target column: category_level_2_sub
# 2025-11-09 15:54:15,785 - data_splitter - INFO -   Unique values: 28
# 2025-11-09 15:54:15,787 - data_splitter - INFO -   Missing values: 0
# 2025-11-09 15:54:15,788 - data_splitter - INFO -
# ================================================================================
# 2025-11-09 15:54:15,789 - data_splitter - INFO - TRAIN/TEST SPLIT
# 2025-11-09 15:54:15,791 - data_splitter - INFO - ================================================================================
# 2025-11-09 15:54:15,806 - data_splitter - INFO - Total samples: 6,681
# 2025-11-09 15:54:15,808 - data_splitter - INFO - Test size: 20.0%
# 2025-11-09 15:54:15,812 - data_splitter - INFO - Train size: 80.0%
# 2025-11-09 15:54:15,841 - data_splitter - INFO -
# ✓ Split completed:
# 2025-11-09 15:54:15,843 - data_splitter - INFO -   Train: 5,344 samples (80.0%)
# 2025-11-09 15:54:15,844 - data_splitter - INFO -   Test:  1,337 samples (20.0%)
# 2025-11-09 15:54:15,846 - data_splitter - INFO -
# --------------------------------------------------------------------------------
# 2025-11-09 15:54:15,849 - data_splitter - INFO - CLASS DISTRIBUTION ANALYSIS
# 2025-11-09 15:54:15,850 - data_splitter - INFO - --------------------------------------------------------------------------------
# 2025-11-09 15:54:15,855 - data_splitter - INFO -
# TRAIN distribution:
# 2025-11-09 15:54:15,858 - data_splitter - INFO -   Arts & Photography            :   146 (  2.7%)
# 2025-11-09 15:54:15,860 - data_splitter - INFO -   Biographies & Memoirs         :   280 (  5.2%)
# 2025-11-09 15:54:15,863 - data_splitter - INFO -   Business & Money              :   123 (  2.3%)
# 2025-11-09 15:54:15,867 - data_splitter - INFO -   Children's Books              :   595 ( 11.1%)
# 2025-11-09 15:54:15,870 - data_splitter - INFO -   Christian Books & Bibles      :   290 (  5.4%)
# 2025-11-09 15:54:15,871 - data_splitter - INFO -   Comics & Graphic Novels       :    86 (  1.6%)
# 2025-11-09 15:54:15,873 - data_splitter - INFO -   Computers & Technology        :    38 (  0.7%)
# 2025-11-09 15:54:15,875 - data_splitter - INFO -   Cookbooks, Food & Wine        :   131 (  2.5%)
# 2025-11-09 15:54:15,876 - data_splitter - INFO -   Crafts, Hobbies & Home        :   122 (  2.3%)
# 2025-11-09 15:54:15,877 - data_splitter - INFO -   Education & Teaching          :    29 (  0.5%)
# 2025-11-09 15:54:15,878 - data_splitter - INFO -   Engineering & Transportation  :    43 (  0.8%)
# 2025-11-09 15:54:15,880 - data_splitter - INFO -   Health, Fitness & Dieting     :    87 (  1.6%)
# 2025-11-09 15:54:15,889 - data_splitter - INFO -   History                       :   182 (  3.4%)
# 2025-11-09 15:54:15,891 - data_splitter - INFO -   Humor & Entertainment         :    75 (  1.4%)
# 2025-11-09 15:54:15,892 - data_splitter - INFO -   Literature & Fiction          : 1,324 ( 24.8%)
# 2025-11-09 15:54:15,894 - data_splitter - INFO -   Medical Books                 :    29 (  0.5%)
# 2025-11-09 15:54:15,897 - data_splitter - INFO -   Mystery, Thriller & Suspense  :   688 ( 12.9%)
# 2025-11-09 15:54:15,900 - data_splitter - INFO -   New, Used & Rental Textbooks  :    48 (  0.9%)
# 2025-11-09 15:54:15,903 - data_splitter - INFO -   Politics & Social Sciences    :   150 (  2.8%)
# 2025-11-09 15:54:15,905 - data_splitter - INFO -   Reference                     :    70 (  1.3%)
# 2025-11-09 15:54:15,906 - data_splitter - INFO -   Religion & Spirituality       :    62 (  1.2%)
# 2025-11-09 15:54:15,909 - data_splitter - INFO -   Romance                       :    94 (  1.8%)
# 2025-11-09 15:54:15,911 - data_splitter - INFO -   Science & Math                :    77 (  1.4%)
# 2025-11-09 15:54:15,913 - data_splitter - INFO -   Science Fiction & Fantasy     :   157 (  2.9%)
# 2025-11-09 15:54:15,915 - data_splitter - INFO -   Self-Help                     :    54 (  1.0%)
# 2025-11-09 15:54:15,917 - data_splitter - INFO -   Sports & Outdoors             :    45 (  0.8%)
# 2025-11-09 15:54:15,920 - data_splitter - INFO -   Teen & Young Adult            :   278 (  5.2%)
# 2025-11-09 15:54:15,923 - data_splitter - INFO -   Travel                        :    41 (  0.8%)
# 2025-11-09 15:54:15,926 - data_splitter - INFO -
# TEST distribution:
# 2025-11-09 15:54:15,930 - data_splitter - INFO -   Arts & Photography            :    37 (  2.8%)
# 2025-11-09 15:54:15,934 - data_splitter - INFO -   Biographies & Memoirs         :    70 (  5.2%)
# 2025-11-09 15:54:15,937 - data_splitter - INFO -   Business & Money              :    31 (  2.3%)
# 2025-11-09 15:54:15,939 - data_splitter - INFO -   Children's Books              :   149 ( 11.1%)
# 2025-11-09 15:54:15,941 - data_splitter - INFO -   Christian Books & Bibles      :    72 (  5.4%)
# 2025-11-09 15:54:15,944 - data_splitter - INFO -   Comics & Graphic Novels       :    22 (  1.6%)
# 2025-11-09 15:54:15,947 - data_splitter - INFO -   Computers & Technology        :     9 (  0.7%)
# 2025-11-09 15:54:15,949 - data_splitter - INFO -   Cookbooks, Food & Wine        :    33 (  2.5%)
# 2025-11-09 15:54:15,953 - data_splitter - INFO -   Crafts, Hobbies & Home        :    30 (  2.2%)
# 2025-11-09 15:54:15,955 - data_splitter - INFO -   Education & Teaching          :     7 (  0.5%)
# 2025-11-09 15:54:15,957 - data_splitter - INFO -   Engineering & Transportation  :    11 (  0.8%)
# 2025-11-09 15:54:15,960 - data_splitter - INFO -   Health, Fitness & Dieting     :    22 (  1.6%)
# 2025-11-09 15:54:15,962 - data_splitter - INFO -   History                       :    46 (  3.4%)
# 2025-11-09 15:54:15,962 - data_splitter - INFO -   Humor & Entertainment         :    19 (  1.4%)
# 2025-11-09 15:54:15,965 - data_splitter - INFO -   Literature & Fiction          :   331 ( 24.8%)
# 2025-11-09 15:54:15,968 - data_splitter - INFO -   Medical Books                 :     7 (  0.5%)
# 2025-11-09 15:54:15,972 - data_splitter - INFO -   Mystery, Thriller & Suspense  :   172 ( 12.9%)
# 2025-11-09 15:54:15,974 - data_splitter - INFO -   New, Used & Rental Textbooks  :    12 (  0.9%)
# 2025-11-09 15:54:15,976 - data_splitter - INFO -   Politics & Social Sciences    :    38 (  2.8%)
# 2025-11-09 15:54:15,979 - data_splitter - INFO -   Reference                     :    17 (  1.3%)
# 2025-11-09 15:54:15,981 - data_splitter - INFO -   Religion & Spirituality       :    16 (  1.2%)
# 2025-11-09 15:54:15,983 - data_splitter - INFO -   Romance                       :    23 (  1.7%)
# 2025-11-09 15:54:15,986 - data_splitter - INFO -   Science & Math                :    19 (  1.4%)
# 2025-11-09 15:54:15,988 - data_splitter - INFO -   Science Fiction & Fantasy     :    39 (  2.9%)
# 2025-11-09 15:54:15,991 - data_splitter - INFO -   Self-Help                     :    14 (  1.0%)
# 2025-11-09 15:54:15,993 - data_splitter - INFO -   Sports & Outdoors             :    11 (  0.8%)
# 2025-11-09 15:54:15,994 - data_splitter - INFO -   Teen & Young Adult            :    70 (  5.2%)
# 2025-11-09 15:54:15,995 - data_splitter - INFO -   Travel                        :    10 (  0.7%)
# 2025-11-09 15:54:15,996 - data_splitter - INFO -
# ✓ All classes present in both TRAIN and TEST
# 2025-11-09 15:54:16,009 - data_splitter - INFO -
# ================================================================================
# 2025-11-09 15:54:16,025 - data_splitter - INFO - SAVING TRAIN/TEST SPLITS
# 2025-11-09 15:54:16,050 - data_splitter - INFO - ================================================================================
# 2025-11-09 15:54:16,052 - data_splitter - INFO - Output directory: ./artifacts_v2/
# 2025-11-09 15:54:16,053 - data_splitter - INFO -
# Saving train data...
# 2025-11-09 15:54:16,848 - data_splitter - INFO - ✓ Train saved: artifacts_v2\train_metadata.csv
# 2025-11-09 15:54:16,849 - data_splitter - INFO -   Shape: (5344, 34)
# 2025-11-09 15:54:16,850 - data_splitter - INFO -
# Saving test data...
# 2025-11-09 15:54:17,013 - data_splitter - INFO - ✓ Test saved: artifacts_v2\test_metadata.csv
# 2025-11-09 15:54:17,014 - data_splitter - INFO -   Shape: (1337, 34)
# 2025-11-09 15:54:17,015 - data_splitter - INFO -
# Saving split info...
# 2025-11-09 15:54:17,018 - data_splitter - INFO - ✓ Split info saved: artifacts_v2\split_info.json
# 2025-11-09 15:54:17,020 - data_splitter - INFO -
# ================================================================================
# 2025-11-09 15:54:17,021 - data_splitter - INFO - ALL FILES SAVED SUCCESSFULLY
# 2025-11-09 15:54:17,022 - data_splitter - INFO - ================================================================================
# 2025-11-09 15:54:17,023 - data_splitter - INFO -
# ================================================================================
# 2025-11-09 15:54:17,024 - data_splitter - INFO - PIPELINE COMPLETED SUCCESSFULLY
# 2025-11-09 15:54:17,025 - data_splitter - INFO - ================================================================================
# 2025-11-09 15:54:17,025 - data_splitter - INFO -
# Generated files:
# 2025-11-09 15:54:17,026 - data_splitter - INFO -   train: artifacts_v2\train_metadata.csv
# 2025-11-09 15:54:17,027 - data_splitter - INFO -   test: artifacts_v2\test_metadata.csv
# 2025-11-09 15:54:17,028 - data_splitter - INFO -   split_info: artifacts_v2\split_info.json
# 2025-11-09 15:54:17,029 - data_splitter - INFO -
# Next steps:
# 2025-11-09 15:54:17,030 - data_splitter - INFO -   → Use train_metadata.csv for feature extraction
# 2025-11-09 15:54:17,031 - data_splitter - INFO -   → Use test_metadata.csv for final evaluation
# 2025-11-09 15:54:17,031 - data_splitter - INFO -   → Check split_info.json for detailed statistics
# 2025-11-09 15:54:17,032 - data_splitter - INFO - ================================================================================
# ✅ Data splitting completed!
#
# Access files in: ./artifacts_v2//
#   - train_metadata.csv
#   - test_metadata.csv
#   - split_info.json

# %%
import pandas as pd
from constants_v2 import PATH_ARTIFACTS_V2, TRAIN_FILE_V2, TEST_FILE_V2
df_train = pd.read_csv(f'{PATH_ARTIFACTS_V2}{TRAIN_FILE_V2}')
df_test = pd.read_csv(f'{PATH_ARTIFACTS_V2}{TEST_FILE_V2}')

print(f"\nTrain columns: {df_train.columns}")
print(f"Test columns: {df_test.columns}")
# Out:
# Train columns: Index(['title', 'subtitle', 'author_name', 'author_about', 'publisher',
#        'publisher_date', 'format', 'page_count', 'language', 'isbn_10',
#        'isbn_13', 'main_category', 'category_level_1_main',
#        'category_level_2_sub', 'category_level_3_detail', 'average_rating',
#        'rating_number', 'price', 'price_numeric', 'description',
#        'features_text', 'dimensions', 'item_weight', 'images', 'videos',
#        'store', 'parent_asin', 'bought_together', 'review_count',
#        'avg_rating_from_reviews', 'rating_std', 'verified_purchase_pct',
#        'helpful_votes_total', 'review_text_avg_length'],
#       dtype='object')
# Test columns: Index(['title', 'subtitle', 'author_name', 'author_about', 'publisher',
#        'publisher_date', 'format', 'page_count', 'language', 'isbn_10',
#        'isbn_13', 'main_category', 'category_level_1_main',
#        'category_level_2_sub', 'category_level_3_detail', 'average_rating',
#        'rating_number', 'price', 'price_numeric', 'description',
#        'features_text', 'dimensions', 'item_weight', 'images', 'videos',
#        'store', 'parent_asin', 'bought_together', 'review_count',
#        'avg_rating_from_reviews', 'rating_std', 'verified_purchase_pct',
#        'helpful_votes_total', 'review_text_avg_length'],
#       dtype='object')

# %%
import importlib
import feature_extractor
importlib.reload(feature_extractor)
from feature_extractor import FeatureExtractor
import pandas as pd

# Apply FeatureExtractor
extractor = FeatureExtractor(
        max_tfidf_features=8000,
        tfidf_ngram_range=(1, 3)
    )
# Out:
# 2025-11-09 15:54:36,139 - feature_extractor - INFO - FeatureExtractor initialized successfully
# 2025-11-09 15:54:36,140 - feature_extractor - INFO - Configuration: {'max_tfidf_features': 8000, 'tfidf_ngram_range': (1, 3), 'tfidf_min_df': 2, 'tfidf_max_df': 0.95}

# %%
#. Fit  train (fits TF-IDF, Scaler, LabelEncoders and Target Encoder)
# Select features numerical, categorical and engineered. also vectorized features
# from title and description columns
extractor.fit(df_train, target_column=TARGET_COLUMN_CATEGORY_LEVEL2)
# Out:
# 2025-11-09 15:54:40,144 - feature_extractor - INFO - ================================================================================
# 2025-11-09 15:54:40,145 - feature_extractor - INFO - FITTING FEATURE EXTRACTOR
# 2025-11-09 15:54:40,145 - feature_extractor - INFO - ================================================================================
# 2025-11-09 15:54:40,146 - feature_extractor - INFO - Input shape: (5344, 34)
# 2025-11-09 15:54:40,147 - feature_extractor - INFO -
# 0. Fitting LabelEncoder for target...
# 2025-11-09 15:54:40,149 - feature_extractor - INFO -    ✓ Target classes: 28
# 2025-11-09 15:54:40,149 - feature_extractor - INFO -       0: Arts & Photography (146 samples)
# 2025-11-09 15:54:40,150 - feature_extractor - INFO -       1: Biographies & Memoirs (280 samples)
# 2025-11-09 15:54:40,151 - feature_extractor - INFO -       2: Business & Money (123 samples)
# 2025-11-09 15:54:40,152 - feature_extractor - INFO -       3: Children's Books (595 samples)
# 2025-11-09 15:54:40,153 - feature_extractor - INFO -       4: Christian Books & Bibles (290 samples)
# 2025-11-09 15:54:40,154 - feature_extractor - INFO -       5: Comics & Graphic Novels (86 samples)
# 2025-11-09 15:54:40,155 - feature_extractor - INFO -       6: Computers & Technology (38 samples)
# 2025-11-09 15:54:40,155 - feature_extractor - INFO -       7: Cookbooks, Food & Wine (131 samples)
# 2025-11-09 15:54:40,156 - feature_extractor - INFO -       8: Crafts, Hobbies & Home (122 samples)
# 2025-11-09 15:54:40,157 - feature_extractor - INFO -       9: Education & Teaching (29 samples)
# 2025-11-09 15:54:40,158 - feature_extractor - INFO -       10: Engineering & Transportation (43 samples)
# 2025-11-09 15:54:40,160 - feature_extractor - INFO -       11: Health, Fitness & Dieting (87 samples)
# 2025-11-09 15:54:40,161 - feature_extractor - INFO -       12: History (182 samples)
# 2025-11-09 15:54:40,162 - feature_extractor - INFO -       13: Humor & Entertainment (75 samples)
# 2025-11-09 15:54:40,163 - feature_extractor - INFO -       14: Literature & Fiction (1324 samples)
# 2025-11-09 15:54:40,165 - feature_extractor - INFO -       15: Medical Books (29 samples)
# 2025-11-09 15:54:40,167 - feature_extractor - INFO -       16: Mystery, Thriller & Suspense (688 samples)
# 2025-11-09 15:54:40,168 - feature_extractor - INFO -       17: New, Used & Rental Textbooks (48 samples)
# 2025-11-09 15:54:40,169 - feature_extractor - INFO -       18: Politics & Social Sciences (150 samples)
# 2025-11-09 15:54:40,170 - feature_extractor - INFO -       19: Reference (70 samples)
# 2025-11-09 15:54:40,171 - feature_extractor - INFO -       20: Religion & Spirituality (62 samples)
# 2025-11-09 15:54:40,172 - feature_extractor - INFO -       21: Romance (94 samples)
# 2025-11-09 15:54:40,173 - feature_extractor - INFO -       22: Science & Math (77 samples)
# 2025-11-09 15:54:40,174 - feature_extractor - INFO -       23: Science Fiction & Fantasy (157 samples)
# 2025-11-09 15:54:40,176 - feature_extractor - INFO -       24: Self-Help (54 samples)
# 2025-11-09 15:54:40,177 - feature_extractor - INFO -       25: Sports & Outdoors (45 samples)
# 2025-11-09 15:54:40,178 - feature_extractor - INFO -       26: Teen & Young Adult (278 samples)
# 2025-11-09 15:54:40,179 - feature_extractor - INFO -       27: Travel (41 samples)
# 2025-11-09 15:54:40,181 - feature_extractor - INFO -
# 1. Preparing text features...
# 2025-11-09 15:55:17,110 - feature_extractor - INFO -    ✓ TF-IDF fitted: 8000 features
# 2025-11-09 15:55:17,111 - feature_extractor - INFO -
# 2. Preparing numerical features...
# 2025-11-09 15:55:17,116 - feature_extractor - INFO -    ✓ Scaler fitted: 6 features
# 2025-11-09 15:55:17,117 - feature_extractor - INFO -    Features: ['price', 'average_rating', 'review_count', 'rating_std', 'verified_purchase_pct', 'helpful_votes_total']
# 2025-11-09 15:55:17,118 - feature_extractor - INFO -
# 3. Preparing categorical features...
# 2025-11-09 15:55:17,137 - feature_extractor - INFO -    ✓ Label encoders fitted: 3 features
# 2025-11-09 15:55:17,139 - feature_extractor - INFO -    Features: ['format', 'binned_rating', 'price_category']
# 2025-11-09 15:55:17,140 - feature_extractor - INFO -
# 4. Identifying engineered features...
# 2025-11-09 15:55:17,141 - feature_extractor - INFO -    ✓ Engineered features: 5
# 2025-11-09 15:55:17,142 - feature_extractor - INFO -    Features: ['title_length', 'desc_length', 'has_series', 'price_rating_ratio', 'engagement_score']
# 2025-11-09 15:55:17,144 - feature_extractor - INFO -
# ================================================================================
# 2025-11-09 15:55:17,145 - feature_extractor - INFO - FEATURE EXTRACTION FIT COMPLETED
# 2025-11-09 15:55:17,146 - feature_extractor - INFO - ================================================================================
# 2025-11-09 15:55:17,147 - feature_extractor - INFO - Total features: 8014
# 2025-11-09 15:55:17,148 - feature_extractor - INFO -   - Text (TF-IDF): 8000
# 2025-11-09 15:55:17,152 - feature_extractor - INFO -   - Numerical: 6
# 2025-11-09 15:55:17,154 - feature_extractor - INFO -   - Categorical: 3
# 2025-11-09 15:55:17,155 - feature_extractor - INFO -   - Engineered: 5
# 2025-11-09 15:55:17,157 - feature_extractor - INFO - ================================================================================

# %%
import numpy as np
print("FeatureExtractor - Book Classification Pipeline")

# Transform train and test (returns X and y)
X_train, y_train, features_train, feature_names = extractor.transform(df_train, target_column=TARGET_COLUMN_CATEGORY_LEVEL2)
X_test, y_test, features_test, _ = extractor.transform(df_test, target_column=TARGET_COLUMN_CATEGORY_LEVEL2)
# Out:
# 2025-11-09 15:56:52,044 - feature_extractor - INFO - ================================================================================
# 2025-11-09 15:56:52,045 - feature_extractor - INFO - TRANSFORMING FEATURES
# 2025-11-09 15:56:52,046 - feature_extractor - INFO - ================================================================================
# 2025-11-09 15:56:52,046 - feature_extractor - INFO - Input shape: (5344, 34)
# 2025-11-09 15:56:52,047 - feature_extractor - INFO -
# 0. Extracting and encoding target...
# 2025-11-09 15:56:52,051 - feature_extractor - INFO -    ✓ Target shape: (5344,)
# 2025-11-09 15:56:52,053 - feature_extractor - INFO -    Target distribution:
# 2025-11-09 15:56:52,054 - feature_extractor - INFO -       0: Arts & Photography             -   146 (  2.7%)
# 2025-11-09 15:56:52,056 - feature_extractor - INFO -       1: Biographies & Memoirs          -   280 (  5.2%)
# 2025-11-09 15:56:52,057 - feature_extractor - INFO -       2: Business & Money               -   123 (  2.3%)
# 2025-11-09 15:56:52,058 - feature_extractor - INFO -       3: Children's Books               -   595 ( 11.1%)
# 2025-11-09 15:56:52,059 - feature_extractor - INFO -       4: Christian Books & Bibles       -   290 (  5.4%)
# 2025-11-09 15:56:52,061 - feature_extractor - INFO -       5: Comics & Graphic Novels        -    86 (  1.6%)
# 2025-11-09 15:56:52,062 - feature_extractor - INFO -       6: Computers & Technology         -    38 (  0.7%)
# 2025-11-09 15:56:52,063 - feature_extractor - INFO -       7: Cookbooks, Food & Wine         -   131 (  2.5%)
# 2025-11-09 15:56:52,065 - feature_extractor - INFO -       8: Crafts, Hobbies & Home         -   122 (  2.3%)
# 2025-11-09 15:56:52,066 - feature_extractor - INFO -       9: Education & Teaching           -    29 (  0.5%)
# 2025-11-09 15:56:52,067 - feature_extractor - INFO -       10: Engineering & Transportation   -    43 (  0.8%)
# 2025-11-09 15:56:52,068 - feature_extractor - INFO -       11: Health, Fitness & Dieting      -    87 (  1.6%)
# 2025-11-09 15:56:52,069 - feature_extractor - INFO -       12: History                        -   182 (  3.4%)
# 2025-11-09 15:56:52,070 - feature_extractor - INFO -       13: Humor & Entertainment          -    75 (  1.4%)
# 2025-11-09 15:56:52,071 - feature_extractor - INFO -       14: Literature & Fiction           -  1324 ( 24.8%)
# 2025-11-09 15:56:52,072 - feature_extractor - INFO -       15: Medical Books                  -    29 (  0.5%)
# 2025-11-09 15:56:52,073 - feature_extractor - INFO -       16: Mystery, Thriller & Suspense   -   688 ( 12.9%)
# 2025-11-09 15:56:52,073 - feature_extractor - INFO -       17: New, Used & Rental Textbooks   -    48 (  0.9%)
# 2025-11-09 15:56:52,074 - feature_extractor - INFO -       18: Politics & Social Sciences     -   150 (  2.8%)
# 2025-11-09 15:56:52,075 - feature_extractor - INFO -       19: Reference                      -    70 (  1.3%)
# 2025-11-09 15:56:52,076 - feature_extractor - INFO -       20: Religion & Spirituality        -    62 (  1.2%)
# 2025-11-09 15:56:52,077 - feature_extractor - INFO -       21: Romance                        -    94 (  1.8%)
# 2025-11-09 15:56:52,078 - feature_extractor - INFO -       22: Science & Math                 -    77 (  1.4%)
# 2025-11-09 15:56:52,080 - feature_extractor - INFO -       23: Science Fiction & Fantasy      -   157 (  2.9%)
# 2025-11-09 15:56:52,081 - feature_extractor - INFO -       24: Self-Help                      -    54 (  1.0%)
# 2025-11-09 15:56:52,083 - feature_extractor - INFO -       25: Sports & Outdoors              -    45 (  0.8%)
# 2025-11-09 15:56:52,084 - feature_extractor - INFO -       26: Teen & Young Adult             -   278 (  5.2%)
# 2025-11-09 15:56:52,085 - feature_extractor - INFO -       27: Travel                         -    41 (  0.8%)
# 2025-11-09 15:56:52,086 - feature_extractor - INFO -
# 1. Transforming text features...
# FeatureExtractor - Book Classification Pipeline
# 2025-11-09 15:57:01,892 - feature_extractor - INFO -    ✓ Text features shape: (5344, 8000)
# 2025-11-09 15:57:01,894 - feature_extractor - INFO -
# 2. Transforming numerical features...
# 2025-11-09 15:57:01,907 - feature_extractor - INFO -    ✓ Numerical features shape: (5344, 6)
# 2025-11-09 15:57:01,908 - feature_extractor - INFO -
# 3. Transforming categorical features...
# 2025-11-09 15:57:01,957 - feature_extractor - INFO -    ✓ Categorical features shape: (5344, 3)
# 2025-11-09 15:57:01,960 - feature_extractor - INFO -
# 4. Extracting engineered features...
# 2025-11-09 15:57:02,018 - feature_extractor - INFO -    ✓ Engineered features shape: (5344, 5)
# 2025-11-09 15:57:02,020 - feature_extractor - INFO -
# 5. Concatenating all features...
# 2025-11-09 15:57:02,220 - feature_extractor - INFO -    ✓ Final feature matrix shape: (5344, 8014)
# 2025-11-09 15:57:02,223 - feature_extractor - INFO -
# ================================================================================
# 2025-11-09 15:57:02,224 - feature_extractor - INFO - FEATURE TRANSFORMATION COMPLETED
# 2025-11-09 15:57:02,226 - feature_extractor - INFO - ================================================================================
# 2025-11-09 15:57:02,227 - feature_extractor - INFO - Total samples: 5344
# 2025-11-09 15:57:02,228 - feature_extractor - INFO - Total features: 8014
# 2025-11-09 15:57:02,229 - feature_extractor - INFO - Target shape: (5344,)
# 2025-11-09 15:57:02,232 - feature_extractor - INFO - ================================================================================
# 2025-11-09 15:57:02,372 - feature_extractor - INFO - ================================================================================
# 2025-11-09 15:57:02,379 - feature_extractor - INFO - TRANSFORMING FEATURES
# 2025-11-09 15:57:02,382 - feature_extractor - INFO - ================================================================================
# 2025-11-09 15:57:02,384 - feature_extractor - INFO - Input shape: (1337, 34)
# 2025-11-09 15:57:02,387 - feature_extractor - INFO -
# 0. Extracting and encoding target...
# 2025-11-09 15:57:02,391 - feature_extractor - INFO -    ✓ Target shape: (1337,)
# 2025-11-09 15:57:02,408 - feature_extractor - INFO -    Target distribution:
# 2025-11-09 15:57:02,409 - feature_extractor - INFO -       0: Arts & Photography             -    37 (  2.8%)
# 2025-11-09 15:57:02,411 - feature_extractor - INFO -       1: Biographies & Memoirs          -    70 (  5.2%)
# 2025-11-09 15:57:02,412 - feature_extractor - INFO -       2: Business & Money               -    31 (  2.3%)
# 2025-11-09 15:57:02,413 - feature_extractor - INFO -       3: Children's Books               -   149 ( 11.1%)
# 2025-11-09 15:57:02,416 - feature_extractor - INFO -       4: Christian Books & Bibles       -    72 (  5.4%)
# 2025-11-09 15:57:02,418 - feature_extractor - INFO -       5: Comics & Graphic Novels        -    22 (  1.6%)
# 2025-11-09 15:57:02,420 - feature_extractor - INFO -       6: Computers & Technology         -     9 (  0.7%)
# 2025-11-09 15:57:02,420 - feature_extractor - INFO -       7: Cookbooks, Food & Wine         -    33 (  2.5%)
# 2025-11-09 15:57:02,422 - feature_extractor - INFO -       8: Crafts, Hobbies & Home         -    30 (  2.2%)
# 2025-11-09 15:57:02,423 - feature_extractor - INFO -       9: Education & Teaching           -     7 (  0.5%)
# 2025-11-09 15:57:02,424 - feature_extractor - INFO -       10: Engineering & Transportation   -    11 (  0.8%)
# 2025-11-09 15:57:02,426 - feature_extractor - INFO -       11: Health, Fitness & Dieting      -    22 (  1.6%)
# 2025-11-09 15:57:02,427 - feature_extractor - INFO -       12: History                        -    46 (  3.4%)
# 2025-11-09 15:57:02,428 - feature_extractor - INFO -       13: Humor & Entertainment          -    19 (  1.4%)
# 2025-11-09 15:57:02,429 - feature_extractor - INFO -       14: Literature & Fiction           -   331 ( 24.8%)
# 2025-11-09 15:57:02,444 - feature_extractor - INFO -       15: Medical Books                  -     7 (  0.5%)
# 2025-11-09 15:57:02,448 - feature_extractor - INFO -       16: Mystery, Thriller & Suspense   -   172 ( 12.9%)
# 2025-11-09 15:57:02,451 - feature_extractor - INFO -       17: New, Used & Rental Textbooks   -    12 (  0.9%)
# 2025-11-09 15:57:02,452 - feature_extractor - INFO -       18: Politics & Social Sciences     -    38 (  2.8%)
# 2025-11-09 15:57:02,455 - feature_extractor - INFO -       19: Reference                      -    17 (  1.3%)
# 2025-11-09 15:57:02,456 - feature_extractor - INFO -       20: Religion & Spirituality        -    16 (  1.2%)
# 2025-11-09 15:57:02,458 - feature_extractor - INFO -       21: Romance                        -    23 (  1.7%)
# 2025-11-09 15:57:02,460 - feature_extractor - INFO -       22: Science & Math                 -    19 (  1.4%)
# 2025-11-09 15:57:02,461 - feature_extractor - INFO -       23: Science Fiction & Fantasy      -    39 (  2.9%)
# 2025-11-09 15:57:02,463 - feature_extractor - INFO -       24: Self-Help                      -    14 (  1.0%)
# 2025-11-09 15:57:02,464 - feature_extractor - INFO -       25: Sports & Outdoors              -    11 (  0.8%)
# 2025-11-09 15:57:02,466 - feature_extractor - INFO -       26: Teen & Young Adult             -    70 (  5.2%)
# 2025-11-09 15:57:02,468 - feature_extractor - INFO -       27: Travel                         -    10 (  0.7%)
# 2025-11-09 15:57:02,469 - feature_extractor - INFO -
# 1. Transforming text features...
# 2025-11-09 15:57:04,849 - feature_extractor - INFO -    ✓ Text features shape: (1337, 8000)
# 2025-11-09 15:57:04,850 - feature_extractor - INFO -
# 2. Transforming numerical features...
# 2025-11-09 15:57:04,855 - feature_extractor - INFO -    ✓ Numerical features shape: (1337, 6)
# 2025-11-09 15:57:04,856 - feature_extractor - INFO -
# 3. Transforming categorical features...
# 2025-11-09 15:57:04,867 - feature_extractor - INFO -    ✓ Categorical features shape: (1337, 3)
# 2025-11-09 15:57:04,868 - feature_extractor - INFO -
# 4. Extracting engineered features...
# 2025-11-09 15:57:04,880 - feature_extractor - INFO -    ✓ Engineered features shape: (1337, 5)
# 2025-11-09 15:57:04,882 - feature_extractor - INFO -
# 5. Concatenating all features...
# 2025-11-09 15:57:04,917 - feature_extractor - INFO -    ✓ Final feature matrix shape: (1337, 8014)
# 2025-11-09 15:57:04,920 - feature_extractor - INFO -
# ================================================================================
# 2025-11-09 15:57:04,921 - feature_extractor - INFO - FEATURE TRANSFORMATION COMPLETED
# 2025-11-09 15:57:04,922 - feature_extractor - INFO - ================================================================================
# 2025-11-09 15:57:04,923 - feature_extractor - INFO - Total samples: 1337
# 2025-11-09 15:57:04,923 - feature_extractor - INFO - Total features: 8014
# 2025-11-09 15:57:04,925 - feature_extractor - INFO - Target shape: (1337,)
# 2025-11-09 15:57:04,927 - feature_extractor - INFO - ================================================================================

# %%
import importlib
import feature_extractor_serializer
importlib.reload(feature_extractor_serializer)
from feature_extractor_serializer import save_features_and_metadata
from constants_v2 import FEATURE_EXTRACTOR_FEATURES_OUTPUT_DIR_V2, MODEL_OUTPUT_DIR_V2

print(f"\nExtractor stats: \n")
print("="*80)
print(f'{extractor.get_stats()}')
#Save for later use

save_features_and_metadata(
        X_train, y_train,
        X_test, y_test,
        feature_names,
        extractor,
        output_dir=FEATURE_EXTRACTOR_FEATURES_OUTPUT_DIR_V2,
        model_dir=MODEL_OUTPUT_DIR_V2)

# After executing  FeatureExtractor obtain the following variables:
'''
X_train         # numpy array (N_train, 5014)
y_train         # numpy array (N_train,)
X_test          # numpy array (N_test, 5014)
y_test          # numpy array (N_test,)
feature_names   # list with 5014 feature names
'''

### **Detailed Features  (5014 total):**
'''
📊 Features:
├── Text (TF-IDF):    5000 features
│   └── tfidf_0, tfidf_1, ..., tfidf_4999
│
├── Numerical:        7 features
│   ├── price
│   ├── average_rating
│   ├── review_count
│   ├── rating_std
│   ├── verified_purchase_pct
│   ├── helpful_votes_total
│   └── avg_review_length
│
├── Categorical:      3 features (encoded)
│   ├── format
│   ├── binned_rating
│   └── price_category
│
└── Engineered:       5 features
    ├── title_length
    ├── desc_length
    ├── has_series
    ├── price_rating_ratio
    └── engagement_score
'''

#loaded_extractor = FeatureExtractor.load('models/feature_extractor')
# Out:
# 2025-11-09 15:57:29,781 - feature_extractor_serializer - INFO - ================================================================================
# 2025-11-09 15:57:29,782 - feature_extractor_serializer - INFO - SAVING ALL OUTPUTS
# 2025-11-09 15:57:29,783 - feature_extractor_serializer - INFO - ================================================================================
# 2025-11-09 15:57:29,785 - feature_extractor_serializer - INFO -
# 1. Saving numpy arrays...
# Extractor stats:
#
# ================================================================================
# {'status': 'fitted', 'total_features': 8014, 'feature_breakdown': {'text': 8000, 'numerical': 6, 'categorical': 3, 'engineered': 5}, 'target_info': {'n_classes': 28, 'classes': ['Arts & Photography', 'Biographies & Memoirs', 'Business & Money', "Children's Books", 'Christian Books & Bibles', 'Comics & Graphic Novels', 'Computers & Technology', 'Cookbooks, Food & Wine', 'Crafts, Hobbies & Home', 'Education & Teaching', 'Engineering & Transportation', 'Health, Fitness & Dieting', 'History', 'Humor & Entertainment', 'Literature & Fiction', 'Medical Books', 'Mystery, Thriller & Suspense', 'New, Used & Rental Textbooks', 'Politics & Social Sciences', 'Reference', 'Religion & Spirituality', 'Romance', 'Science & Math', 'Science Fiction & Fantasy', 'Self-Help', 'Sports & Outdoors', 'Teen & Young Adult', 'Travel']}, 'config': {'max_tfidf_features': 8000, 'tfidf_ngram_range': (1, 3), 'tfidf_min_df': 2, 'tfidf_max_df': 0.95}, 'feature_names': {'text': ['tfidf_0', 'tfidf_1', 'tfidf_2', 'tfidf_3', 'tfidf_4', 'tfidf_5', 'tfidf_6', 'tfidf_7', 'tfidf_8', 'tfidf_9', 'tfidf_10', 'tfidf_11', 'tfidf_12', 'tfidf_13', 'tfidf_14', 'tfidf_15', 'tfidf_16', 'tfidf_17', 'tfidf_18', 'tfidf_19', 'tfidf_20', 'tfidf_21', 'tfidf_22', 'tfidf_23', 'tfidf_24', 'tfidf_25', 'tfidf_26', 'tfidf_27', 'tfidf_28', 'tfidf_29', 'tfidf_30', 'tfidf_31', 'tfidf_32', 'tfidf_33', 'tfidf_34', 'tfidf_35', 'tfidf_36', 'tfidf_37', 'tfidf_38', 'tfidf_39', 'tfidf_40', 'tfidf_41', 'tfidf_42', 'tfidf_43', 'tfidf_44', 'tfidf_45', 'tfidf_46', 'tfidf_47', 'tfidf_48', 'tfidf_49', 'tfidf_50', 'tfidf_51', 'tfidf_52', 'tfidf_53', 'tfidf_54', 'tfidf_55', 'tfidf_56', 'tfidf_57', 'tfidf_58', 'tfidf_59', 'tfidf_60', 'tfidf_61', 'tfidf_62', 'tfidf_63', 'tfidf_64', 'tfidf_65', 'tfidf_66', 'tfidf_67', 'tfidf_68', 'tfidf_69', 'tfidf_70', 'tfidf_71', 'tfidf_72', 'tfidf_73', 'tfidf_74', 'tfidf_75', 'tfidf_76', 'tfidf_77', 'tfidf_78', 'tfidf_79', 'tfidf_80', 'tfidf_81', 'tfidf_82', 'tfidf_83', 'tfidf_84', 'tfidf_85', 'tfidf_86', 'tfidf_87', 'tfidf_88', 'tfidf_89', 'tfidf_90', 'tfidf_91', 'tfidf_92', 'tfidf_93', 'tfidf_94', 'tfidf_95', 'tfidf_96', 'tfidf_97', 'tfidf_98', 'tfidf_99', 'tfidf_100', 'tfidf_101', 'tfidf_102', 'tfidf_103', 'tfidf_104', 'tfidf_105', 'tfidf_106', 'tfidf_107', 'tfidf_108', 'tfidf_109', 'tfidf_110', 'tfidf_111', 'tfidf_112', 'tfidf_113', 'tfidf_114', 'tfidf_115', 'tfidf_116', 'tfidf_117', 'tfidf_118', 'tfidf_119', 'tfidf_120', 'tfidf_121', 'tfidf_122', 'tfidf_123', 'tfidf_124', 'tfidf_125', 'tfidf_126', 'tfidf_127', 'tfidf_128', 'tfidf_129', 'tfidf_130', 'tfidf_131', 'tfidf_132', 'tfidf_133', 'tfidf_134', 'tfidf_135', 'tfidf_136', 'tfidf_137', 'tfidf_138', 'tfidf_139', 'tfidf_140', 'tfidf_141', 'tfidf_142', 'tfidf_143', 'tfidf_144', 'tfidf_145', 'tfidf_146', 'tfidf_147', 'tfidf_148', 'tfidf_149', 'tfidf_150', 'tfidf_151', 'tfidf_152', 'tfidf_153', 'tfidf_154', 'tfidf_155', 'tfidf_156', 'tfidf_157', 'tfidf_158', 'tfidf_159', 'tfidf_160', 'tfidf_161', 'tfidf_162', 'tfidf_163', 'tfidf_164', 'tfidf_165', 'tfidf_166', 'tfidf_167', 'tfidf_168', 'tfidf_169', 'tfidf_170', 'tfidf_171', 'tfidf_172', 'tfidf_173', 'tfidf_174', 'tfidf_175', 'tfidf_176', 'tfidf_177', 'tfidf_178', 'tfidf_179', 'tfidf_180', 'tfidf_181', 'tfidf_182', 'tfidf_183', 'tfidf_184', 'tfidf_185', 'tfidf_186', 'tfidf_187', 'tfidf_188', 'tfidf_189', 'tfidf_190', 'tfidf_191', 'tfidf_192', 'tfidf_193', 'tfidf_194', 'tfidf_195', 'tfidf_196', 'tfidf_197', 'tfidf_198', 'tfidf_199', 'tfidf_200', 'tfidf_201', 'tfidf_202', 'tfidf_203', 'tfidf_204', 'tfidf_205', 'tfidf_206', 'tfidf_207', 'tfidf_208', 'tfidf_209', 'tfidf_210', 'tfidf_211', 'tfidf_212', 'tfidf_213', 'tfidf_214', 'tfidf_215', 'tfidf_216', 'tfidf_217', 'tfidf_218', 'tfidf_219', 'tfidf_220', 'tfidf_221', 'tfidf_222', 'tfidf_223', 'tfidf_224', 'tfidf_225', 'tfidf_226', 'tfidf_227', 'tfidf_228', 'tfidf_229', 'tfidf_230', 'tfidf_231', 'tfidf_232', 'tfidf_233', 'tfidf_234', 'tfidf_235', 'tfidf_236', 'tfidf_237', 'tfidf_238', 'tfidf_239', 'tfidf_240', 'tfidf_241', 'tfidf_ ...
# 2025-11-09 15:57:30,238 - feature_extractor_serializer - INFO -    ✓ X_train saved: (5344, 8014)
# 2025-11-09 15:57:30,240 - feature_extractor_serializer - INFO -    ✓ y_train saved: (5344,)
# 2025-11-09 15:57:30,362 - feature_extractor_serializer - INFO -    ✓ X_test saved: (1337, 8014)
# 2025-11-09 15:57:30,364 - feature_extractor_serializer - INFO -    ✓ y_test saved: (1337,)
# 2025-11-09 15:57:30,364 - feature_extractor_serializer - INFO -
# 2. Saving feature names...
# 2025-11-09 15:57:30,378 - feature_extractor_serializer - INFO -    ✓ feature_names.json saved: 8014 features
# 2025-11-09 15:57:30,380 - feature_extractor_serializer - INFO -
# 3. Saving class names and mapping...
# 2025-11-09 15:57:30,384 - feature_extractor_serializer - INFO -    ✓ class_names.json saved: 28 classes
# 2025-11-09 15:57:30,385 - feature_extractor_serializer - INFO -
# 4. Saving FeatureExtractor...
# 2025-11-09 15:57:30,387 - feature_extractor - INFO -
# Saving FeatureExtractor to ./artifacts_v2//models/...
# 2025-11-09 15:57:30,565 - feature_extractor - INFO -    ✓ FeatureExtractor saved successfully
# 2025-11-09 15:57:30,567 - feature_extractor - INFO -    Files: text_vectorizer.joblib, scaler.joblib, label_encoders.joblib
# 2025-11-09 15:57:30,568 - feature_extractor - INFO -    Files: target_label_encoder.joblib
# 2025-11-09 15:57:30,569 - feature_extractor - INFO -    Metadata: feature_extractor_metadata.json
# 2025-11-09 15:57:30,570 - feature_extractor_serializer - INFO -    ✓ FeatureExtractor saved to: ./artifacts_v2//models/
# 2025-11-09 15:57:30,571 - feature_extractor_serializer - INFO -
# 5. Saving summary statistics...
# 2025-11-09 15:57:30,574 - feature_extractor_serializer - INFO -    ✓ summary.json saved
# '\n📊 Features:\n├── Text (TF-IDF):    5000 features\n│   └── tfidf_0, tfidf_1, ..., tfidf_4999\n│\n├── Numerical:        7 features\n│   ├── price\n│   ├── average_rating\n│   ├── review_count\n│   ├── rating_std\n│   ├── verified_purchase_pct\n│   ├── helpful_votes_total\n│   └── avg_review_length\n│\n├── Categorical:      3 features (encoded)\n│   ├── format\n│   ├── binned_rating\n│   └── price_category\n│\n└── Engineered:       5 features\n    ├── title_length\n    ├── desc_length\n    ├── has_series\n    ├── price_rating_ratio\n    └── engagement_score\n'

# %%
import numpy as np
import json

from constants_v2 import X_TRAIN_FILE_V2, Y_TRAIN_FILE_V2, X_TEST_FILE_V2, Y_TEST_FILE_V2
from constants_v2 import CLASS_NAMES_FILE_V2, CLASS_WEIGHTS_FILE_V2,FEATURE_NAMES_FILE_V2
from constants_v2 import REPORT_XGBOOST_CLASSIFICATION_REPORT_FILE_V2, REPORT_XGBOOST_FEATURE_IMPORTANCE_FILE_V2
from constants_v2 import REPORT_XGBOOST_METRICS_FILE_V2,REPORT_XGBOOST_MODEL_FILE_V2, REPORT_XGBOOST_CONFUSION_MATRIX_FILE_V2

print("\n" + "=" * 80)
print("STEP 4: MODEL TRAINING")
print("=" * 80)

# ------------------------------------------------------------------------------
# 1. LOAD DATA FROM STEP 3
# ------------------------------------------------------------------------------
print("Loading data ")

X_train = np.load(X_TRAIN_FILE_V2)
y_train = np.load(Y_TRAIN_FILE_V2)
X_test = np.load(X_TEST_FILE_V2)
y_test = np.load(Y_TEST_FILE_V2)

# Load class names
with open(CLASS_NAMES_FILE_V2, 'r') as f:
    class_info = json.load(f)
    class_names = class_info['class_names']

# Load feature names (optional, for visualizations)
with open(FEATURE_NAMES_FILE_V2, 'r') as f:
    feature_info = json.load(f)
    feature_names = feature_info['feature_names']

# Load class weights (if available from Step 2)
try:
    with open(CLASS_WEIGHTS_FILE_V2, 'r') as f:
        class_weights = json.load(f)
except FileNotFoundError:
    class_weights = None
    print("No class_weights.json found, will use default balancing")

print(f"Data loaded:")
print(f"  Training samples: {len(X_train)}")
print(f"  Test samples: {len(X_test)}")
print(f"  Features: {X_train.shape[1]}")
print(f"  Classes: {len(class_names)}")
# Out:
# ================================================================================
# STEP 4: MODEL TRAINING
# ================================================================================
# Loading data
# Data loaded:
#   Training samples: 5344
#   Test samples: 1337
#   Features: 8014
#   Classes: 28

# %%
import importlib
import model_trainer
importlib.reload(model_trainer)
from model_trainer import XGBoostTrainer
# ------------------------------------------------------------------------------
# 2. TRAIN XGBOOST MODEL
# ------------------------------------------------------------------------------
print("\\n" + "="*80)
print("Training XGBoost Model...")
print("="*80)

xgb_trainer = XGBoostTrainer(
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    class_names=class_names,
    class_weights=class_weights,
    output_dir='models',
    n_estimators=200,
    max_depth=8,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    early_stopping_rounds=10
)
# Out:
# 2025-11-09 15:57:59,594 - model_trainer - INFO - Initialized XGBoost Trainer
# 2025-11-09 15:57:59,595 - model_trainer - INFO - Training samples: 5344, Test samples: 1337
# 2025-11-09 15:57:59,596 - model_trainer - INFO - Number of features: 8014
# 2025-11-09 15:57:59,598 - model_trainer - INFO - Number of classes: 28
# \n================================================================================
# Training XGBoost Model...
# ================================================================================

# %%
# Train
xgb_trainer.train()
# Out:
# 2025-11-09 15:58:03,008 - model_trainer - INFO - Training XGBoost with parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'early_stopping_rounds': 10}
# 2025-11-09 15:58:03,010 - model_trainer - WARNING - Error computing sample weights: invalid literal for int() with base 10: 'Arts & Photography'
# 2025-11-09 15:58:03,010 - model_trainer - INFO - Falling back to no sample weights
# 2025-11-09 15:58:03,011 - model_trainer - INFO - Attempting to use early stopping with 10 rounds
# 2025-11-09 15:58:03,012 - model_trainer - WARNING - XGBoost version doesn't support early_stopping_rounds in fit(): XGBClassifier.fit() got an unexpected keyword argument 'early_stopping_rounds'
# 2025-11-09 15:58:03,012 - model_trainer - INFO - Training without early stopping...
# [0]	validation_0-mlogloss:2.96824
# [1]	validation_0-mlogloss:2.77368
# [2]	validation_0-mlogloss:2.61851
# [3]	validation_0-mlogloss:2.49837
# [4]	validation_0-mlogloss:2.39904
# [5]	validation_0-mlogloss:2.31911
# [6]	validation_0-mlogloss:2.24507
# [7]	validation_0-mlogloss:2.18254
# [8]	validation_0-mlogloss:2.12482
# [9]	validation_0-mlogloss:2.07531
# [10]	validation_0-mlogloss:2.03073
# [11]	validation_0-mlogloss:1.98883
# [12]	validation_0-mlogloss:1.95306
# [13]	validation_0-mlogloss:1.91922
# [14]	validation_0-mlogloss:1.88925
# [15]	validation_0-mlogloss:1.86219
# [16]	validation_0-mlogloss:1.83511
# [17]	validation_0-mlogloss:1.81123
# [18]	validation_0-mlogloss:1.78655
# [19]	validation_0-mlogloss:1.76468
# [20]	validation_0-mlogloss:1.74279
# [21]	validation_0-mlogloss:1.72362
# [22]	validation_0-mlogloss:1.70633
# [23]	validation_0-mlogloss:1.69063
# [24]	validation_0-mlogloss:1.67371
# [25]	validation_0-mlogloss:1.65921
# [26]	validation_0-mlogloss:1.64544
# [27]	validation_0-mlogloss:1.63359
# [28]	validation_0-mlogloss:1.62037
# [29]	validation_0-mlogloss:1.61020
# [30]	validation_0-mlogloss:1.59823
# [31]	validation_0-mlogloss:1.58788
# [32]	validation_0-mlogloss:1.57852
# [33]	validation_0-mlogloss:1.57005
# [34]	validation_0-mlogloss:1.56000
# [35]	validation_0-mlogloss:1.55149
# [36]	validation_0-mlogloss:1.54383
# [37]	validation_0-mlogloss:1.53481
# [38]	validation_0-mlogloss:1.52891
# [39]	validation_0-mlogloss:1.52295
# [40]	validation_0-mlogloss:1.51609
# [41]	validation_0-mlogloss:1.51044
# [42]	validation_0-mlogloss:1.50460
# [43]	validation_0-mlogloss:1.50138
# [44]	validation_0-mlogloss:1.49661
# [45]	validation_0-mlogloss:1.49154
# [46]	validation_0-mlogloss:1.48710
# [47]	validation_0-mlogloss:1.48131
# [48]	validation_0-mlogloss:1.47686
# [49]	validation_0-mlogloss:1.47380
# [50]	validation_0-mlogloss:1.47025
# [51]	validation_0-mlogloss:1.46699
# [52]	validation_0-mlogloss:1.46299
# [53]	validation_0-mlogloss:1.46030
# [54]	validation_0-mlogloss:1.45844
# [55]	validation_0-mlogloss:1.45633
# [56]	validation_0-mlogloss:1.45454
# [57]	validation_0-mlogloss:1.45220
# [58]	validation_0-mlogloss:1.45041
# [59]	validation_0-mlogloss:1.44751
# [60]	validation_0-mlogloss:1.44513
# [61]	validation_0-mlogloss:1.44391
# [62]	validation_0-mlogloss:1.44209
# [63]	validation_0-mlogloss:1.44120
# [64]	validation_0-mlogloss:1.43958
# [65]	validation_0-mlogloss:1.43907
# [66]	validation_0-mlogloss:1.43710
# [67]	validation_0-mlogloss:1.43558
# [68]	validation_0-mlogloss:1.43329
# [69]	validation_0-mlogloss:1.43189
# [70]	validation_0-mlogloss:1.43014
# [71]	validation_0-mlogloss:1.42889
# [72]	validation_0-mlogloss:1.42831
# [73]	validation_0-mlogloss:1.42747
# [74]	validation_0-mlogloss:1.42633
# [75]	validation_0-mlogloss:1.42455
# [76]	validation_0-mlogloss:1.42356
# [77]	validation_0-mlogloss:1.42297
# [78]	validation_0-mlogloss:1.42218
# [79]	validation_0-mlogloss:1.42141
# [80]	validation_0-mlogloss:1.42149
# [81]	validation_0-mlogloss:1.42079
# [82]	validation_0-mlogloss:1.42108
# [83]	validation_0-mlogloss:1.42025
# [84]	validation_0-mlogloss:1.41979
# [85]	validation_0-mlogloss:1.41903
# [86]	validation_0-mlogloss:1.41928
# [87]	validation_0-mlogloss:1.41764
# [88]	validation_0-mlogloss:1.41756
# [89]	validation_0-mlogloss:1.41727
# [90]	validation_0-mlogloss:1.41644
# [91]	validation_0-mlogloss:1.41699
# [92]	validation_0-mlogloss:1.41700
# [93]	validation_0-mlogloss:1.41651
# [94]	validation_0-mlogloss:1.41645
# [95]	validation_0-mlogloss:1.41572
# [96]	validation_0-mlogloss:1.41594
# [97]	validation_0-mlogloss:1.41604
# [98]	validation_0-mlogloss:1.41594
# [99]	validation_0-mlogloss:1.41537
# [100]	validation_0-mlogloss:1.41587
# [101]	validation_0-mlogloss:1.41531
# [102]	validation_0-mlogloss:1.41531
# [103]	validation_0-mlogloss:1.41581
# [104]	validation_0-mlogloss:1.41599
# [105]	validation_0-mlogloss:1.41608
# [106]	validation_0-mlogloss:1.41562
# [107]	validation_0-mlogloss:1.41509
# [108]	validation_0-mlogloss:1.41487
# [109]	validation_0-mlogloss:1.41481
# [110]	validation_0-mlogloss:1.41482
# [111]	validation_0-mlogloss:1.41418
# [112]	validation_0-mlogloss:1.41474
# [113]	validation_0-mlogloss:1.41477
# [114]	validation_0-mlogloss:1.41512
# [115]	validation_0-mlogloss:1.41499
# [116]	validation_0-mlogloss:1.41522
# [117]	validation_0-mlogloss:1.41525
# [118]	validation_0-mlogloss:1.41593
# [119]	validation_0-mlogloss:1.41573
# [120]	validation_0-mlogloss:1.41586
# [121]	validation_0-mlogloss:1.41559
# [122]	validation_0-mlogloss:1.41594
# [123]	validation_0-mlogloss:1.41621
# [124]	validation_0-mlogloss:1.41674
# [125]	validation_0-mlogloss:1.41695
# [126]	validation_0-mlogloss:1.41748
# [127]	validation_0-mlogloss:1.41817
# [128]	validation_0-mlogloss:1.41797
# [129]	validation_0-mlogloss:1.41789
# [130]	validation_0-mlogloss:1.41841
# [131]	validation_0-mlogloss:1.41870
# [132]	validation_0-mlogloss:1.41878
# [133]	validation_0-mlogloss:1.41896
# [134]	validation_0-mlogloss:1.41941
# [135]	validation_0-mlogloss:1.41955
# [136]	validation_0-mlogloss:1.41945
# [137]	validation_0-mlogloss:1.41982
# [138]	validation_0-mlogloss:1.42047
# [139]	validation_0-mlogloss:1.42050
# [140]	validation_0-mlogloss:1.42081
# [141]	validation_0-mlogloss:1.42084
# [142]	validation_0-mlogloss:1.42045
# [143]	validation_0-mlogloss:1.42049
# [144]	validation_0-mlogloss:1.42087
# [145]	validation_0-mlogloss:1.42106
# [146]	validation_0-mlogloss:1.42115
# [147]	validation_0-mlogloss:1.42123
# [148]	validation_0-mlogloss:1.42174
# [149]	validation_0-mlogloss:1.42252
# [150]	validation_0-mlogloss:1.42274
# [151]	validation_0-mlogloss:1.42338
# [152]	validation_0-mlogloss:1.42373
# [153]	validation_0-mlogloss:1.42353
# [154]	validation_0-mlogloss:1.42381
# [155]	validation_0-mlogloss:1.42392
# [156]	validation_0-mlogloss:1.42469
# [157]	validation_0-mlogloss:1.42510
# [158]	validation_0-mlogloss:1.42554
# [159]	validation_0-mlogloss:1.42559
# [160]	validation_0-mlogloss:1.42540
# [161]	validation_0-mlogloss:1.42601
# [162]	validation_0-mlogloss:1.42684
# [163]	validation_0-mlogloss:1.42745
# [164]	validation_0-mlogloss:1.42772
# [165]	validation_0-mlogloss:1.42807
# [166]	validation_0-mlogloss:1.42876
# [167]	validation_0-mlogloss:1.42938
# [168]	validation_0-mlogloss:1.43010
# [169]	validation_0-mlogloss:1.43073
# [170]	validation_0-mlogloss:1.43157
# [171]	validation_0-mlogloss:1.43225
# [172]	validation_0-mlogloss:1.43297
# [173]	validation_0-mlogloss:1.43295
# [174]	validation_0-mlogloss:1.43374
# [175]	validation_0-mlogloss:1.43467
# [176]	validation_0-mlogloss:1.43528
# [177]	validation_0-mlogloss:1.43562
# [178]	validation_0-mlogloss:1.43570
# [179]	validation_0-mlogloss:1.43675
# [180]	validation_0-mlogloss:1.43665
# [181]	validation_0-mlogloss:1.43654
# [182]	validation_0-mlogloss:1.43688
# [183]	validation_0-mlogloss:1.43750
# [184]	validation_0-mlogloss:1.43746
# [185]	validation_0-mlogloss:1.43834
# [186]	validation_0-mlogloss:1.43859
# [187]	validation_0-mlogloss:1.43865
# [188]	validation_0-mlogloss:1.43898
# [189]	validation_0-mlogloss:1.44028
# [190]	validation_0-mlogloss:1.44069
# [191]	validation_0-mlogloss:1.44124
# [192]	validation_0-mlogloss:1.44115
# [193]	validation_0-mlogloss:1.44135
# [194]	validation_0-mlogloss:1.44122
# [195]	validation_0-mlogloss:1.44123
# [196]	validation_0-mlogloss:1.44172
# [197]	validation_0-mlogloss:1.44157
# [198]	validation_0-mlogloss:1.44194
# [199]	validation_0-mlogloss:1.44260
# 2025-11-09 16:27:09,875 - model_trainer - INFO - XGBoost training completed

# %%
# Evaluate on test set
xgb_test_metrics = xgb_trainer.evaluate(X_test, y_test, 'test')
# Out:
# 2025-11-09 16:27:42,674 - model_trainer - INFO - Evaluating XGBoost on test set...
# 2025-11-09 16:27:43,037 - model_trainer - INFO - TEST METRICS:
# 2025-11-09 16:27:43,037 - model_trainer - INFO -   Accuracy: 0.5849
# 2025-11-09 16:27:43,038 - model_trainer - INFO -   Precision (weighted): 0.5816
# 2025-11-09 16:27:43,039 - model_trainer - INFO -   Recall (weighted): 0.5849
# 2025-11-09 16:27:43,039 - model_trainer - INFO -   F1-Score (weighted): 0.5558

# %%
# Cross-validation
xgb_cv_results = xgb_trainer.cross_validate(cv=2, scoring='f1_weighted')
# Out:
# 2025-11-09 16:45:01,566 - model_trainer - INFO - Performing 2-fold cross-validation...
# 2025-11-09 17:11:33,443 - model_trainer - INFO - CV f1_weighted: 0.5446 (+/- 0.0003)

# %%
import importlib
import constants_v2
importlib.reload(constants_v2)

from constants_v2 import REPORT_XGBOOST_CLASSIFICATION_REPORT_FILE_V2, REPORT_XGBOOST_FEATURE_IMPORTANCE_FILE_V2
from constants_v2 import REPORT_XGBOOST_METRICS_FILE_V2,REPORT_XGBOOST_MODEL_FILE_V2, REPORT_XGBOOST_CONFUSION_MATRIX_FILE_V2

# Visualizations
xgb_trainer.plot_confusion_matrix(
    y_test,
    xgb_trainer.model.predict(X_test),
    normalize=True,
    save_path=REPORT_XGBOOST_CONFUSION_MATRIX_FILE_V2
)
# Out:
# 2025-11-09 17:12:09,988 - model_trainer - INFO - Confusion matrix saved to ./artifacts_v2//reports//xgboost_confusion_matrix.png

# %%
xgb_trainer.plot_feature_importance(
    top_n=20,
    feature_names=feature_names,
    save_path=REPORT_XGBOOST_FEATURE_IMPORTANCE_FILE_V2
)
# Out:
# 2025-11-09 17:12:13,116 - model_trainer - INFO - Feature importance plot saved to ./artifacts_v2//reports//xgboost_feature_importance.png
# 2025-11-09 17:12:13,117 - model_trainer - INFO -
# Top 20 Features:
# 2025-11-09 17:12:13,118 - model_trainer - INFO -   1. tfidf_3401: 0.0018
# 2025-11-09 17:12:13,119 - model_trainer - INFO -   2. tfidf_3733: 0.0018
# 2025-11-09 17:12:13,120 - model_trainer - INFO -   3. tfidf_6649: 0.0020
# 2025-11-09 17:12:13,122 - model_trainer - INFO -   4. tfidf_1424: 0.0020
# 2025-11-09 17:12:13,122 - model_trainer - INFO -   5. tfidf_7649: 0.0020
# 2025-11-09 17:12:13,123 - model_trainer - INFO -   6. tfidf_5805: 0.0020
# 2025-11-09 17:12:13,124 - model_trainer - INFO -   7. tfidf_5713: 0.0020
# 2025-11-09 17:12:13,125 - model_trainer - INFO -   8. tfidf_6192: 0.0021
# 2025-11-09 17:12:13,126 - model_trainer - INFO -   9. tfidf_7366: 0.0021
# 2025-11-09 17:12:13,126 - model_trainer - INFO -   10. tfidf_639: 0.0021
# 2025-11-09 17:12:13,127 - model_trainer - INFO -   11. tfidf_6186: 0.0023
# 2025-11-09 17:12:13,128 - model_trainer - INFO -   12. tfidf_7189: 0.0024
# 2025-11-09 17:12:13,129 - model_trainer - INFO -   13. tfidf_5859: 0.0024
# 2025-11-09 17:12:13,129 - model_trainer - INFO -   14. tfidf_5680: 0.0026
# 2025-11-09 17:12:13,130 - model_trainer - INFO -   15. tfidf_1954: 0.0026
# 2025-11-09 17:12:13,131 - model_trainer - INFO -   16. tfidf_2438: 0.0027
# 2025-11-09 17:12:13,131 - model_trainer - INFO -   17. tfidf_6795: 0.0042
# 2025-11-09 17:12:13,132 - model_trainer - INFO -   18. tfidf_3538: 0.0044
# 2025-11-09 17:12:13,132 - model_trainer - INFO -   19. tfidf_3384: 0.0063
# 2025-11-09 17:12:13,133 - model_trainer - INFO -   20. tfidf_3865: 0.0229

# %%
xgb_trainer.save_classification_report(
    y_test,
    xgb_trainer.model.predict(X_test),
    save_path=REPORT_XGBOOST_CLASSIFICATION_REPORT_FILE_V2
)
# Save model
xgb_trainer.save_model(REPORT_XGBOOST_MODEL_FILE_V2)

# Save metrics

with open(REPORT_XGBOOST_METRICS_FILE_V2, 'w') as f:
    json.dump({
        'test_metrics': xgb_test_metrics,
        'cv_results': xgb_cv_results
    }, f, indent=2)
# Out:
# 2025-11-09 17:12:30,534 - model_trainer - INFO -
# XGBoost Classification Report:
#                               precision    recall  f1-score   support
#
#           Arts & Photography     0.6538    0.4595    0.5397        37
#        Biographies & Memoirs     0.4603    0.4143    0.4361        70
#             Business & Money     0.6571    0.7419    0.6970        31
#             Children's Books     0.7228    0.8926    0.7988       149
#     Christian Books & Bibles     0.6329    0.6944    0.6623        72
#      Comics & Graphic Novels     0.8182    0.4091    0.5455        22
#       Computers & Technology     1.0000    0.7778    0.8750         9
#       Cookbooks, Food & Wine     0.7500    0.8182    0.7826        33
#       Crafts, Hobbies & Home     0.4286    0.3000    0.3529        30
#         Education & Teaching     0.4000    0.2857    0.3333         7
# Engineering & Transportation     1.0000    0.2727    0.4286        11
#    Health, Fitness & Dieting     0.2308    0.1364    0.1714        22
#                      History     0.4118    0.3043    0.3500        46
#        Humor & Entertainment     1.0000    0.1579    0.2727        19
#         Literature & Fiction     0.5183    0.8127    0.6329       331
#                Medical Books     0.2500    0.1429    0.1818         7
# Mystery, Thriller & Suspense     0.6786    0.6628    0.6706       172
# New, Used & Rental Textbooks     0.7778    0.5833    0.6667        12
#   Politics & Social Sciences     0.2632    0.1316    0.1754        38
#                    Reference     0.3333    0.1176    0.1739        17
#      Religion & Spirituality     0.7500    0.1875    0.3000        16
#                      Romance     0.2000    0.0435    0.0714        23
#               Science & Math     0.5385    0.3684    0.4375        19
#    Science Fiction & Fantasy     0.5217    0.3077    0.3871        39
#                    Self-Help     0.3333    0.0714    0.1176        14
#            Sports & Outdoors     0.4000    0.1818    0.2500        11
#           Teen & Young Adult     0.7838    0.4143    0.5421        70
#                       Travel     0.0000    0.0000    0.0000        10
#
#                     accuracy                         0.5849      1337
#                    macro avg     0.5541    0.3818    0.4233      1337
#                 weighted avg     0.5816    0.5849    0.5558      1337
#
# 2025-11-09 17:12:30,536 - model_trainer - INFO - Classification report saved to ./artifacts_v2//reports//xgboost_classification_report.txt
# 2025-11-09 17:12:30,645 - model_trainer - INFO - Model saved to ./artifacts_v2//reports//xgboost_model.pkl
# 2025-11-09 17:12:30,647 - model_trainer - INFO - Model metadata saved to ./artifacts_v2//reports//xgboost_model_metadata.json

# %%
import importlib
import book_classifier
importlib.reload(book_classifier)
from book_classifier import example_single_prediction, BookClassifier, example_batch_prediction

import feature_extractor
importlib.reload(feature_extractor)
from feature_extractor import FeatureExtractor

from constants_v2 import REPORT_XGBOOST_MODEL_FILE_V2, MODEL_OUTPUT_DIR_V2

example_single_prediction(REPORT_XGBOOST_MODEL_FILE_V2, MODEL_OUTPUT_DIR_V2)

example_batch_prediction(REPORT_XGBOOST_MODEL_FILE_V2, MODEL_OUTPUT_DIR_V2)
# Out:
# 2025-11-10 12:29:17,979 - feature_extractor - INFO -
# Loading FeatureExtractor from ./artifacts_v2//models/...
# 2025-11-10 12:29:17,984 - feature_extractor - INFO - FeatureExtractor initialized successfully
# 2025-11-10 12:29:17,985 - feature_extractor - INFO - Configuration: {'max_tfidf_features': 8000, 'tfidf_ngram_range': [1, 3], 'tfidf_min_df': 2, 'tfidf_max_df': 0.95}
# ================================================================================
# EXAMPLE 2: Batch Prediction
# ================================================================================
# Loading model...
# ✓ Model loaded from ./artifacts_v2//reports//xgboost_model.pkl
# 2025-11-10 12:29:18,079 - feature_extractor - INFO -    ✓ FeatureExtractor loaded successfully
# 2025-11-10 12:29:18,081 - feature_extractor - INFO -    Target classes: 28
# 2025-11-10 12:29:18,143 - feature_extractor - INFO - ✓ Features for inference: (3, 8014)
# ✓ Feature extractor loaded
# ✓ Loaded 28 classes
#
# ✓ Classifier ready!
#
#
# Results:
#
#   Python Crash Course
#     → Christian Books & Bibles (31.9%)
#
#   The Great Gatsby
#     → Literature & Fiction (83.0%)
#
#   Healthy Cooking Made Easy
#     → Cookbooks, Food & Wine (97.0%)

# %%
# !pip install fastapi uvicorn pydantic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fastapi in c:\users\admin\appdata\roaming\python\python313\site-packages (0.121.1)
# Requirement already satisfied: uvicorn in c:\users\admin\appdata\roaming\python\python313\site-packages (0.38.0)
# Requirement already satisfied: pydantic in c:\users\admin\appdata\roaming\python\python313\site-packages (2.12.4)
# Requirement already satisfied: starlette<0.50.0,>=0.40.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from fastapi) (0.49.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\admin\appdata\roaming\python\python313\site-packages (from fastapi) (0.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\admin\appdata\roaming\python\python313\site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\admin\appdata\roaming\python\python313\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\admin\appdata\roaming\python\python313\site-packages (from starlette<0.50.0,>=0.40.0->fastapi) (4.11.0)
# Requirement already satisfied: idna>=2.8 in c:\users\admin\appdata\roaming\python\python313\site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\admin\appdata\roaming\python\python313\site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: click>=7.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from uvicorn) (8.3.0)
# Requirement already satisfied: h11>=0.8 in c:\users\admin\appdata\roaming\python\python313\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: colorama in c:\users\admin\appdata\roaming\python\python313\site-packages (from click>=7.0->uvicorn) (0.4.6)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Python313\python.exe -m pip install --upgrade pip

# %%
# !python.exe .\test_api_client.py
# Out:
# ^C

# %% [markdown]
#     ╔══════════════════════════════════════════════════════════════════════════════╗
#     ║                    TEST CLIENT - BOOK CLASSIFIER API                         ║
#     ╚══════════════════════════════════════════════════════════════════════════════╝
#
#
# Make sure the API is running at http://localhost:8005
# If not running, execute first: python api.py
#
#
# ================================================================================
# TEST MENU
# ================================================================================
# 1. Test: Single book
# 2. Test: Multiple books
# 3. Test: Edge cases
# 4. Interactive mode
# 5. Speed benchmark
# 6. Run all tests
# 7. Exit
#
# Choose an option (1-7): 6
#
# ================================================================================
# RUNNING ALL TESTS
# ================================================================================
#
# ================================================================================
# TEST 1: Single Book Prediction
# ================================================================================
#
# ✓ API Status: running
#
# ================================================================================
# 📚 Book: The Da Vinci Code
# ================================================================================
#
# 🎯 Predicted Category: Literature & Fiction
# 📊 Confidence: 71.6%
#
# 🏆 Top 3 Predictions:
#   1. Literature & Fiction                ███████████████████████████████████ 71.6%
#   2. Mystery, Thriller & Suspense        ██████ 13.6%
#   3. Christian Books & Bibles            ████ 8.6%
#
# ================================================================================
# TEST 2: Multiple Books Prediction
# ================================================================================
#
# ================================================================================
# 📚 Book: Python Crash Course
# ================================================================================
#
# 🎯 Predicted Category: Christian Books & Bibles
# 📊 Confidence: 36.3%
#
# 🏆 Top 3 Predictions:
#   1. Christian Books & Bibles            ██████████████████ 36.3%
#   2. Literature & Fiction                ███████████████ 30.7%
#   3. Computers & Technology              █████ 11.2%
#
# ================================================================================
# 📚 Book: The Great Gatsby
# ================================================================================
#
# 🎯 Predicted Category: Literature & Fiction
# 📊 Confidence: 86.6%
#
# 🏆 Top 3 Predictions:
#   1. Literature & Fiction                ███████████████████████████████████████████ 86.6%
#   2. Christian Books & Bibles            ██ 4.9%
#   3. Humor & Entertainment               █ 3.4%
#
# ================================================================================
# 📚 Book: Healthy Cooking Made Easy
# ================================================================================
#
# 🎯 Predicted Category: Cookbooks, Food & Wine
# 📊 Confidence: 97.1%
#
# 🏆 Top 3 Predictions:
#   1. Cookbooks, Food & Wine              ████████████████████████████████████████████████ 97.1%
#   2. Literature & Fiction                 1.5%
#   3. Christian Books & Bibles             0.6%
#
# ================================================================================
# 📚 Book: Harry Potter and the Sorcerer's Stone
# ================================================================================
#
# 🎯 Predicted Category: Children's Books
# 📊 Confidence: 77.3%
#
# 🏆 Top 3 Predictions:
#   1. Children's Books                    ██████████████████████████████████████ 77.3%
#   2. Teen & Young Adult                  █████ 10.9%
#   3. Christian Books & Bibles            ███ 7.6%
#
# ================================================================================
# 📚 Book: Becoming
# ================================================================================
#
# 🎯 Predicted Category: Biographies & Memoirs
# 📊 Confidence: 40.1%
#
# 🏆 Top 3 Predictions:
#   1. Biographies & Memoirs               ████████████████████ 40.1%
#   2. Children's Books                    █████████ 19.9%
#   3. Christian Books & Bibles            █████████ 19.2%
#
# ================================================================================
# TEST 3: Edge Cases
# ================================================================================
#
# 📌 Test: Very Expensive Book
#
# ================================================================================
# 📚 Book: Expensive Book
# ================================================================================
#
# 🎯 Predicted Category: Literature & Fiction
# 📊 Confidence: 54.7%
#
# 🏆 Top 3 Predictions:
#   1. Literature & Fiction                ███████████████████████████ 54.7%
#   2. Christian Books & Bibles            ████ 8.3%
#   3. Romance                             ███ 7.1%
#
# 📌 Test: Very Cheap Book
#
# ================================================================================
# 📚 Book: Cheap Book
# ================================================================================
#
# 🎯 Predicted Category: Literature & Fiction
# 📊 Confidence: 74.9%
#
# 🏆 Top 3 Predictions:
#   1. Literature & Fiction                █████████████████████████████████████ 74.9%
#   2. Children's Books                    █████ 10.1%
#   3. Mystery, Thriller & Suspense        ██ 4.7%
#
# 📌 Test: Short Description
#
# ================================================================================
# 📚 Book: Short Description
# ================================================================================
#
# 🎯 Predicted Category: Literature & Fiction
# 📊 Confidence: 77.4%
#
# 🏆 Top 3 Predictions:
#   1. Literature & Fiction                ██████████████████████████████████████ 77.4%
#   2. Christian Books & Bibles            ███ 6.4%
#   3. Mystery, Thriller & Suspense        ██ 4.9%
#
# ================================================================================
# API SPEED BENCHMARK
# ================================================================================
#
# Making 10 requests...
#   Request 1: 2038.5ms
#   Request 2: 2053.5ms
#   Request 3: 2092.1ms
#   Request 4: 2060.9ms
#   Request 5: 2053.9ms
#   Request 6: 2061.7ms
#   Request 7: 2049.4ms
#   Request 8: 2062.4ms
#   Request 9: 2085.9ms
#   Request 10: 2050.4ms
#
# ================================================================================
# BENCHMARK RESULTS
# ================================================================================
# Total requests:   10
# Average time:     2060.9ms
# Minimum time:     2038.5ms
# Maximum time:     2092.1ms
# Requests/second:  0.5
#
# ================================================================================
# ✓ ALL TESTS COMPLETED
# ================================================================================
#
# ================================================================================
# TEST MENU
# ================================================================================
# 1. Test: Single book
# 2. Test: Multiple books
# 3. Test: Edge cases
# 4. Interactive mode
# 5. Speed benchmark
# 6. Run all tests
# 7. Exit

# %%
# !python api.py
# Out:
# ^C
